# %% [markdown]
# ##CalTest Home Selection Electricity
#
# *The purpose of home selection is to find a reprentative set of homes for CalTest. Representitiveness was determined by the following criteria:*
#
# 1. Contractor (Completed by preferred contractors)
# 2. Pre-retrofit air leakage (25th-90th percentile of CFM50)
# 3. Energy intesity (25th-90th percentile)
# 4. Elec HVAC Unit
# 5. Stories (1)
# 6. Total conditioned area (20th-80th percentile)
# 7. Total electrictiy use (>40th percentile)
# 8. Total elec savings (>40th percentile)
# 9. Electic realization rate (25th-75th percentile)
# 10. Fit on heating degree days regression ($R^2>.9$)
# 11. Year built (>1950)
# 12. Climate grouping (evenly distributed across 3 main groups)
# 13. Utility (representative sample from each IOU)
#
# The final dataset `CalTest_test_homes_v1_4-1.csv` consists of 28 homes that form a representative distribution of home types, climate areas, and measures, while also meeting the selection criteria above.
#
# Test homes are also displayed in the likely format for vendors in the excel spreadsheet `CalTest_beta_v3_April_2.xls`.

# %% [markdown]
# ####Steps in home selection

# %% [markdown]
# Begin with combined dataset of cleaned home charateristics with weather normalized data.
#
#     CalTest_combined_project_data_cleaned.csv
#     CalTest_combined_usage_data_cleaned.csv

# %%
import pandas as pd
import matplotlib as plt


util = "scg"
climategroup = 5

#specify dataset
useData = "/Users/matthewgee/Projects/CalTest/data/final/" + str(util) +"_CalTest_data_prepped.csv"

#specify path
savePath = "/Users/matthewgee/Projects/CalTest/data/final/"


#Define switch class
class switch(object):
    def __init__(self, value):
        self.value = value
        self.fall = False

    def __iter__(self):
        """Return the match method once, then stop"""
        yield self.match
        raise StopIteration
    
    def match(self, *args):
        """Indicate whether or not to enter a case suite"""
        if self.fall or not args:
            return True
        elif self.value in args: # changed for v1.5, see below
            self.fall = True
            return True
        else:
            return False

# %%
#set utility and climate group for run
#loop through scg, sdge pge
#loop throug climate group 1,2,3
util = "scg"
climategroup = 5

#Output filenames
dataSelect = "/Users/matthewgee/Projects/CalTest/data/final/" + str(util) + "_CalTest_elec_group_" + str(climategroup) +".csv"
combinedSelect = "/Users/matthewgee/Projects/CalTest/data/final/" + str(util) + "_combined_CalTest_elec.csv"
combinedSelectX = "/Users/matthewgee/Projects/CalTest/data/final/" + str(util) + "_combined_CalTest_elec.xls"

# %% [markdown]
# ####Read in data as dataframes, and identify homes by utility

# %%
df = pd.read_csv(useData)
len(df)
df
# Out:
#               siteid audit_date compdate_apponline retrofit_complete_date  \
# 0   SGHDPS1525777059  11oct2011                NaN              10feb2012
# 1   SGHDPS1525777094  05oct2011                NaN              10feb2012
# 2   SGHDPS1525777108  12oct2011                NaN              10feb2012
# 3   SGHDPS1525779780  03jan2012                NaN              13feb2012
# 4   SGHDPS1525783449  29dec2011          02apr2012              29may2012
# 5   SGHDPS1525783456  06jan2012                NaN              31jan2012
# 6   SGHDPS1525798860  15nov2011                NaN              22feb2012
# 7   SGHDPS1525808346  10dec2011                NaN              28feb2012
# 8   SGHDPS1525808762  27sep2011                NaN              14mar2012
# 9   SGHDPS1525812520  20sep2011                NaN              02mar2012
# 10  SGHDPS1525812598  03jan2012                NaN              10mar2012
# 11  SGHDPS1525820728  05sep2011                NaN              05mar2012
# 12  SGHDPS1525846059  02dec2011                NaN              10mar2012
# 13  SGHDPS1525846761  15dec2011                NaN              12mar2012
# 14  SGHDPS1525851177  02dec2011                NaN              04apr2012
# 15  SGHDPS1525861076  04feb2012                NaN              26mar2012
# 16  SGHDPS1525861742  31aug2011                NaN              11dec2013
# 17  SGHDPS1525958233  05jan2012                NaN              02apr2012
# 18  SGHDPS1525970393  30jan2012                NaN              13apr2012
# 19  SGHDPS1525975342  25aug2011                NaN              04apr2012
# 20  SGHDPS1525975566  04feb2012                NaN              09apr2012
# 21  SGHDPS1525985748  23jan2012          25jan2012              12aug2012
# 22  SGHDPS1525985775  02feb2012          16mar2012              21may2012
# 23  SGHDPS1525988997  17feb2012                NaN              26apr2012
# 24  SGHDPS1525993634  05jan2012                NaN              17apr2012
# 25  SGHDPS1526030095  02apr2012                NaN              04may2012
# 26  SGHDPS1526035280  16may2012          02jul2012              05jul2012
# 27  SGHDPS1526043470  28dec2011                NaN              07may2012
# 28  SGHDPS1526060512  23feb2012          07may2012              08may2012
# 29  SGHDPS1526086884  17jan2012                NaN              16may2012
# 30  SGHDPS1526105088  31jan2012          15mar2012              24may2012
# 31  SGHDPS1526106330  31jan2012          22mar2012              25may2012
# 32  SGHDPS1526107369  23jan2012                NaN              30may2012
# 33  SGHDPS1526107380  20jan2012          28apr2012              04jun2012
# 34  SGHDPS1526111208  27feb2012          22mar2012              29may2012
# 35  SGHDPS1526142993  23apr2012          17may2012              04jun2012
# 36  SGHDPS1526183929  09jun2012          19jul2012              24jul2012
# 37  SGHDPS1526215611  06jun2012          11aug2012              20sep2012
# 38  SGHDPS1526227775  24apr2012          07jun2012              15jun2012
# 39  SGHDPS1526228000  30may2012          30aug2012              06sep2012
# 40  SGHDPS1526228089  12jun2012          26jul2012              19sep2012
# 41  SGHDPS1526228340  31mar2012          12jun2012              21jun2012
# 42  SGHDPS1526228362  01feb2012          20apr2012              25jun2012
# 43  SGHDPS1526232212  13jun2012          19jul2012              19sep2012
# 44  SGHDPS1526244770  23mar2012          05jun2012              16jul2012
# 45  SGHDPS1526257975  13aug2012          19oct2011              14aug2012
# 46  SGHDPS1526258330  02feb2012          06jun2012              16jul2012
# 47  SGHDPS1526258331  27feb2012          07sep2012              18oct2012
# 48  SGHDPS1526258332  26mar2012          21may2012              23jul2012
# 49  SGHDPS1526258335  10feb2012          03mar2012              04jul2012
# 50  SGHDPS1526258337  11nov2011          28dec2012              11aug2012
# 51  SGHDPS1526258338  10feb2012          17may2012              12aug2012
# 52  SGHDPS1526258339  23mar2012          15may2012              04jul2012
# 53  SGHDPS1526258340  27jan2012          02apr2012              30jul2012
# 54  SGHDPS1526258341  27jan2012          13mar2012              05jul2012
# 55  SGHDPS1526258342  23jan2012          20dec2011              12aug2012
# 56  SGHDPS1526258343  02dec2011          17apr2012              05jul2012
# 57  SGHDPS1526258344  11may2012          23feb2012              27jul2012
# 58  SGHDPS1526258345  11may2012          05jan2012              19sep2012
# 59  SGHDPS1526258357  29may2012          31aug2012              21sep2012
#                  ...        ...                ...                    ...
#
#    lacountyreleasesigned electrictyutility gasutility       climate  zipcode  \
# 0                     No          Pasadena   SoCalGas             9    91107
# 1                     No             LADWP   SoCalGas             9    91604
# 2                    Yes             LADWP   SoCalGas             9    91316
# 3                     No          Glendale   SoCalGas             9    91208
# 4                     No          Pasadena   SoCalGas             9    91104
# 5                    Yes          Pasadena   SoCalGas             9    91107
# 6                     No             LADWP   SoCalGas             9    91411
# 7                     No             LADWP   SoCalGas             9    90041
# 8                     No               PGE   SoCalGas            13    93618
# 9                     No             LADWP   SoCalGas             9    91406
# 10                   Yes          Pasadena   SoCalGas             9    91107
# 11                    No             LADWP   SoCalGas             9    90008
# 12                   Yes          Glendale   SoCalGas             9    91202
# 13                    No             LADWP   SoCalGas             9    90032
# 14                   Yes             LADWP   SoCalGas             9    91303
# 15                    No             LADWP   SoCalGas  Not Provided    90066
# 16                    No             LADWP   SoCalGas             9    90039
# 17                    No             LADWP   SoCalGas             9    91401
# 18                    No             LADWP   SoCalGas             9    90035
# 19                   Yes             LADWP   SoCalGas             6    90041
# 20                    No             LADWP   SoCalGas             9    91307
# 21                    No             LADWP   SoCalGas             8    90043
# 22                   Yes             LADWP   SoCalGas             8    90045
# 23                    No               PGE   SoCalGas            13    94903
# 24                   Yes             LADWP   SoCalGas             8    90036
# 25                    No               PGE   SoCalGas            12    93458
# 26                    No             LADWP   SoCalGas             6    90501
# 27                    No               PGE   SoCalGas            16    93631
# 28                    No             LADWP   SoCalGas             6    90047
# 29                   Yes             LADWP   SoCalGas             9    91423
# 30                   Yes             LADWP   SoCalGas             9    91304
# 31                    No          Glendale   SoCalGas             9    91207
# 32                    No             LADWP   SoCalGas             6    91307
# 33                   Yes             LADWP   SoCalGas             9    91506
# 34                   Yes             LADWP   SoCalGas             9    90008
# 35                   Yes             LADWP   SoCalGas             9    91344
# 36                    No             LADWP   SoCalGas             9    91344
# 37                    No             LADWP   SoCalGas             9    91423
# 38                    No             LADWP   SoCalGas             9    90039
# 39                    No             LADWP   SoCalGas             9    90041
# 40                    No               PGE   SoCalGas             5    93455
# 41                    No             LADWP   SoCalGas             9    91307
# 42                   Yes             LADWP   SoCalGas             9    91316
# 43                    No               PGE   SoCalGas            13    93245
# 44                    No             LADWP   SoCalGas             9    91324
# 45                    No               PGE   SoCalGas             4    93401
# 46                    No             LADWP   SoCalGas             9    91344
# 47                    No             LADWP   SoCalGas             9    90035
# 48                    No             LADWP   SoCalGas             9    91311
# 49                    No             LADWP   SoCalGas             8    91436
# 50                    No             LADWP   SoCalGas             8    90291
# 51                    No             LADWP   SoCalGas             8    90008
# 52                    No             LADWP   SoCalGas             8    90026
# 53                    No             LADWP   SoCalGas             8    90016
# 54                    No             LADWP   SoCalGas             8    90049
# 55                   Yes             LADWP   SoCalGas             8    90004
# 56                   Yes             LADWP   SoCalGas             8    91343
# 57                    No               PGE   SoCalGas             4    93455
# 58                    No               PGE   SoCalGas             5    93455
# 59                    No             LADWP   SoCalGas             9    91307
#                      ...               ...        ...           ...      ...
#
#     year_built  pre_conditioned_area foundation_type      ht_fuel  \
# 0         1953                1582.0    Raised Floor  Natural Gas
# 1         1950                2049.0    Raised Floor  Natural Gas
# 2         1939                2444.0    Raised Floor  Natural Gas
# 3         1948                2175.0    Raised Floor  Natural Gas
# 4         1924                2053.0    Raised Floor  Natural Gas
# 5         1951                2300.0   Slab on Grade  Natural Gas
# 6         1951                1559.0    Raised Floor  Natural Gas
# 7         1952                 784.0    Raised Floor  Natural Gas
# 8         1978                2262.0   Slab on Grade  Natural Gas
# 9         1957                1346.0    Raised Floor  Natural Gas
# 10        1978                1656.0   Slab on Grade  Natural Gas
# 11        1959                1890.0             NaN  Natural Gas
# 12        1926                1604.0    Raised Floor  Natural Gas
# 13        1941                1447.0    Raised Floor  Natural Gas
# 14        1956                1090.0   Slab on Grade  Natural Gas
# 15        1943                1352.0   Slab on Grade  Natural Gas
# 16        1915                 800.0    Raised Floor  Natural Gas
# 17        1950                2378.0    Raised Floor  Natural Gas
# 18        1928                2000.0    Raised Floor  Natural Gas
# 19        1912                2466.0    Raised Floor  Natural Gas
# 20        1957                1570.0   Slab on Grade  Natural Gas
# 21        1938                1377.0    Raised Floor  Natural Gas
# 22        1948                1264.0    Raised Floor  Natural Gas
# 23        1908                1792.0    Raised Floor  Natural Gas
# 24        1929                2535.0    Raised Floor  Natural Gas
# 25        1958                1800.0   Slab on Grade  Natural Gas
# 26        1955                2000.0    Raised Floor  Natural Gas
# 27        1937                2275.0    Raised Floor  Natural Gas
# 28        1922                1552.0    Raised Floor  Natural Gas
# 29        1951                1661.0             NaN  Natural Gas
# 30        1952                3600.0    Raised Floor  Natural Gas
# 31        1924                1500.0    Raised Floor  Natural Gas
# 32        1963                1679.0   Slab on Grade  Natural Gas
# 33        1951                1085.0             NaN  Natural Gas
# 34        1954                2166.0    Raised Floor  Natural Gas
# 35        1964                1971.0   Slab on Grade  Natural Gas
# 36        1965                2625.0   Slab on Grade  Natural Gas
# 37        1948                1390.0    Raised Floor  Natural Gas
# 38        1931                1267.5    Raised Floor  Natural Gas
# 39        1928                1244.0    Raised Floor  Natural Gas
# 40        1982                1700.0   Slab on Grade  Natural Gas
# 41        1960                1565.0   Slab on Grade  Natural Gas
# 42        1948                3320.0    Raised Floor  Natural Gas
# 43        1974                2155.0   Slab on Grade  Natural Gas
# 44        1960                2470.0    Raised Floor  Natural Gas
# 45        1973                2147.0    Raised Floor  Natural Gas
# 46        1990                5382.0   Slab on Grade  Natural Gas
# 47        1935                1674.0    Raised Floor  Natural Gas
# 48        1971                1890.0   Slab on Grade  Natural Gas
# 49        1948                1406.0    Raised Floor  Natural Gas
# 50        1944                1016.0    Raised Floor  Natural Gas
# 51        1956                1702.0    Raised Floor  Natural Gas
# 52        1942                1110.0   Slab on Grade  Natural Gas
# 53        1930                 895.0    Raised Floor  Natural Gas
# 54        1948                2600.0   Slab on Grade  Natural Gas
# 55        1916                1790.0    Raised Floor  Natural Gas
# 56        1961                1780.0   Slab on Grade  Natural Gas
# 57        1992                2100.0   Slab on Grade  Natural Gas
# 58        1998                2233.0   Slab on Grade  Natural Gas
# 59        1957                1642.0    Raised Floor  Natural Gas
#            ...                   ...             ...          ...
#
#    water_heater_type_existing centralac  projected_gas_savings  \
# 0                 Natural Gas       Yes                 297.00
# 1                    Electric       Yes                 136.00
# 2                 Natural Gas       Yes                 283.00
# 3                 Natural Gas       Yes                   0.00
# 4                 Natural Gas       Yes                  57.00
# 5                 Natural Gas       Yes                  82.00
# 6                 Natural Gas       Yes                 259.00
# 7                 Natural Gas       Yes                  -1.13
# 8                 Natural Gas       Yes                 297.00
# 9                 Natural Gas       Yes                 156.00
# 10                Natural Gas       Yes                 184.00
# 11                Natural Gas       Yes                 199.00
# 12                Natural Gas       Yes                 380.00
# 13                Natural Gas       Yes                 243.00
# 14                Natural Gas       Yes                 259.00
# 15                Natural Gas       Yes                 121.00
# 16                Natural Gas       Yes                  40.00
# 17                Natural Gas       Yes                 186.00
# 18                Natural Gas       Yes                 229.00
# 19                Natural Gas       Yes                 460.00
# 20                Natural Gas       Yes                 174.00
# 21                Natural Gas        No                 153.00
# 22                Natural Gas        No                 185.00
# 23                Natural Gas       Yes                 377.00
# 24                Natural Gas       Yes                 135.00
# 25                Natural Gas       Yes                 714.00
# 26                Natural Gas       Yes                 440.00
# 27                Natural Gas       Yes                 800.00
# 28                Natural Gas       Yes                 191.00
# 29                Natural Gas       Yes                 272.00
# 30                Natural Gas       Yes                 159.00
# 31                Natural Gas       Yes                 449.00
# 32                Natural Gas       Yes                 151.00
# 33                Natural Gas       Yes                 121.00
# 34                Natural Gas       Yes                 147.00
# 35                Natural Gas       Yes                  37.00
# 36                Natural Gas       Yes                 388.00
# 37                Natural Gas       Yes                 144.00
# 38                Natural Gas       Yes                 119.00
# 39                Natural Gas       Yes                  98.00
# 40                Natural Gas       Yes                 258.00
# 41                Natural Gas       Yes                  99.00
# 42                Natural Gas       Yes                 339.00
# 43                Natural Gas       Yes                 161.00
# 44                Natural Gas       Yes                 152.00
# 45                Natural Gas       Yes                 717.00
# 46                Natural Gas       Yes                  92.00
# 47                Natural Gas       Yes                 127.00
# 48                Natural Gas       Yes                 258.00
# 49                Natural Gas       Yes                 202.00
# 50                Natural Gas        No                 216.00
# 51                Natural Gas       Yes                 401.00
# 52                Natural Gas       Yes                 187.00
# 53                Natural Gas        No                   0.08
# 54                Natural Gas       Yes                 289.00
# 55                Natural Gas       Yes                 304.00
# 56                Natural Gas       Yes                 261.00
# 57                Natural Gas       Yes                 385.00
# 58                Natural Gas       Yes                 148.00
# 59                Natural Gas       Yes                 106.00
#                           ...       ...                    ...
#
#     projected_elec_savings  shell_leakage_cfm50_existing  cfm25_pre  \
# 0                     3981                        6483.0        NaN
# 1                     1164                        3600.0        NaN
# 2                     5753                        4750.0        NaN
# 3                     3392                        4089.0        NaN
# 4                      972                        3494.0        NaN
# 5                     1636                        4667.0        NaN
# 6                     5029                        4484.0        NaN
# 7                     -629                        1456.0        NaN
# 8                     6365                        2060.0        NaN
# 9                     2708                        4545.0        NaN
# 10                    2584                        3680.0        NaN
# 11                     333                           NaN        NaN
# 12                    5210                        4323.0        NaN
# 13                     593                        4573.0        NaN
# 14                     410                           NaN        NaN
# 15                      51                        3020.0        NaN
# 16                     726                        2852.0        NaN
# 17                    2162                        3900.0        NaN
# 18                    2914                        5485.0        NaN
# 19                    4303                        9200.0        NaN
# 20                    2517                        2890.0        NaN
# 21                     -58                        3524.0        NaN
# 22                      49                        2214.0        NaN
# 23                    4494                        5432.0        NaN
# 24                     666                        3799.0        NaN
# 25                     995                           4.9        NaN
# 26                     656                        7990.0        486
# 27                    9288                        2918.0        NaN
# 28                     953                        4424.0        NaN
# 29                    1132                        3039.0        NaN
# 30                    1312                        2202.0        NaN
# 31                     945                        2241.0        NaN
# 32                    5467                        2280.0        NaN
# 33                    1821                        1950.0        NaN
# 34                    2882                        2198.0        NaN
# 35                    1710                        2339.0        NaN
# 36                    7385                        4900.0       2000
# 37                    3499                        2524.0        185
# 38                    1768                        2813.0        212
# 39                     270                        2902.0        246
# 40                     631                        3982.0        404
# 41                   -5599                        2152.0        NaN
# 42                    7366                        5416.0        583
# 43                    2746                        1365.0        229
# 44                    1743                           NaN        NaN
# 45                   -3119                        4010.0        431
# 46                    2621                        7141.0        168
# 47                    3119                        4679.0        NaN
# 48                    4756                        1991.0        NaN
# 49                    5992                        3807.0        NaN
# 50                    2808                        3314.0        NaN
# 51                     881                        8200.0        NaN
# 52                     450                        3500.0        NaN
# 53                     -29                        1383.0        NaN
# 54                     458                        6062.0        NaN
# 55                    2216                        8132.0        NaN
# 56                    3355                        2182.0        NaN
# 57                    1218                        7350.0        738
# 58                     191                        2886.0        NaN
# 59                    1486                        1090.0        NaN
#                        ...                           ...        ...
#
#    duct_leakage_existing
# 0                 Hazard ...
# 1                    NaN ...
# 2                    NaN ...
# 3                    NaN ...
# 4                    NaN ...
# 5                    NaN ...
# 6                      0 ...
# 7                      0 ...
# 8                    NaN ...
# 9                    NaN ...
# 10                   NaN ...
# 11                Hazard ...
# 12                Hazard ...
# 13                   NaN ...
# 14                Hazard ...
# 15                   NaN ...
# 16                   NaN ...
# 17                   NaN ...
# 18                   NaN ...
# 19                     0 ...
# 20                   NaN ...
# 21                   NaN ...
# 22                   NaN ...
# 23                     0 ...
# 24                   NaN ...
# 25                Hazard ...
# 26                   486 ...
# 27                     0 ...
# 28                     0 ...
# 29                Hazard ...
# 30                   NaN ...
# 31                Hazard ...
# 32                   NaN ...
# 33                   NaN ...
# 34                Hazard ...
# 35                   NaN ...
# 36                  2000 ...
# 37                   185 ...
# 38                   212 ...
# 39                   246 ...
# 40                   404 ...
# 41                Hazard ...
# 42                   583 ...
# 43                   229 ...
# 44                Hazard ...
# 45                   431 ...
# 46                   168 ...
# 47                   NaN ...
# 48                   NaN ...
# 49                   NaN ...
# 50                   NaN ...
# 51                Hazard ...
# 52                   NaN ...
# 53                   NaN ...
# 54                   NaN ...
# 55                   NaN ...
# 56                Hazard ...
# 57                   738 ...
# 58                   NaN ...
# 59                Hazard ...
#                      ...
#
# [72 rows x 99 columns]

# %%
df.elec_realization.describe()
df.climate.value_counts()
# Out:
# 9               44
# 8               12
# 6                5
# 5                3
# 13               3
# 4                2
# Not Provided     1
# 12               1
# 16               1
# dtype: int64

# %% [markdown]
# ###Create climate zone specific datasets

# %%
#Create climate zone-specific datasets
# PG&E (12, 3), (4, 11, 2), (13,16,5,&7) 
for case in switch(climategroup):
    if case(1):
        df = df[(df['climate']==12) | (df['climate']==3)]
        df = df[df.preffered_contractor==1]
        break
    if case(2):
        df = df[(df['climate']==11) | (df['climate']==2) | (df['climate']==4)]
        df= df[df.cooltype1!="None"]
        break
    if case(3):
        df = df[(df['climate']==13) | (df['climate']==16) | (df['climate']==5) | (df['climate']==7)]
        df= df[df.cooltype1!="None"]
        break
    if case(4):
        df = df[(df['climate']=="9")]
        break 
    if case(5):
        df = df[(df['climate']!="9")]
        break
    if case():
        print "No climate group"
        break
len(df)
# Out:
# 28

# %% [markdown]
# Subset by climate zone to ensure representativeness

# %% [markdown]
# Subset by contractor (moved to the end of file)

# %%
df.contractor.value_counts()
# Out:
# Series([], dtype: int64)

# %%
#I no longer screen by contractor size
#g = df.groupby('contractor')
#df = g.filter(lambda x: len(x) > 5)
#df.contractor.value_counts()

# %%
#df = df[df.preffered_contractor==1]
#len(df)

# %% [markdown]
# ####Filter by quantile of pre-retrofit CFM50

# %%
df.shell_leakage_cfm50_existing.describe()
# Out:
# count      28.000000
# mean     4096.889286
# std      2342.287178
# min         4.900000
# 25%      2263.500000
# 50%      3661.500000
# 75%      5385.500000
# max      9200.000000
# Name: shell_leakage_cfm50_existing, dtype: float64

# %% [markdown]
# Histogram of pre-retrofi CFM50

# %%
df.shell_leakage_cfm50_existing.hist(figsize=(10,5))

# %% [markdown]
# Remove lower 25% percentile and top 10 percentile of CFM50

# %%
df = df[df.shell_leakage_cfm50_existing < df.shell_leakage_cfm50_existing.quantile(.90)]
df = df[df.shell_leakage_cfm50_existing.quantile(.25) < df.shell_leakage_cfm50_existing]
df.shell_leakage_cfm50_existing.hist(figsize(10,5))

# %% [markdown]
# New distribution of CFM50

# %%
len(df)
# Out:
# 18

# %% [markdown]
# ###Select by energy intensity

# %%
df.energy_intensity.hist(figsize=(10,5))

# %% [markdown]
# Remove lower 25 percentile and top 10 percentile of CFM50

# %%
#df = df[df.energy_intensity < df.energy_intensity.quantile(.90)]
#df = df[df.energy_intensity.quantile(.25) < df.energy_intensity]
#df.energy_intensity.hist(figsize=(10,5))

# %% [markdown]
# ###Must have central AC

# %%
#df= df[df.cooltype1!="None"]
len(df)
# Out:
# 18

# %% [markdown]
# ###Remove based on number of stories
# For now we are including only 1 story buildings

# %%
#df.stories_above_grade.value_counts()

# %%
#df = df[df.stories_above_grade==1]
len(df)
# Out:
# 18

# %% [markdown]
# ###Subset by total area
#
# Look at the distribution of total conditioned area across the subset of homes.

# %%
df.pre_conditioned_area.hist(figsize=(10,5))

# %% [markdown]
# Dropping the lower and upper 20% of the distribution

# %%
df = df[df.pre_conditioned_area < df.pre_conditioned_area.quantile(.80)]
df = df[df.pre_conditioned_area.quantile(.20) < df.pre_conditioned_area]
df.pre_conditioned_area.hist(figsize=(10,5))

# %% [markdown]
# ###Subset on total electricity savings
# We select for the upper 60% and remove only the top 3% from the total realized savings distribution to ensure there is enough signal in the sample homes for testing.

# %%
df.electricity_savings.hist(figsize=(10,5))

# %%
df = df[df.electricity_savings < df.electricity_savings.quantile(.97)]
df = df[df.electricity_savings.quantile(.40) < df.electricity_savings]
df.electricity_savings.hist(figsize=(10,5))

# %%
len(df)
# Out:
# 6

# %% [markdown]
# ###Subset on Realization Rate
#
# Examining the distribution of realization rates for gas and electricity

# %%
#Gas Realization rates
df.gas_realization.hist()

# %%
#Electricity Realization rates
df.elec_realization.hist()

# %% [markdown]
# Drop the upper and lower 25th percentiles for both gas and electrcity

# %%
df = df[df.elec_realization < df.elec_realization.quantile(.80)]
df = df[df.elec_realization.quantile(.20) < df.elec_realization]
df.elec_realization.hist(figsize=(10,5))

# %%
#df = df[df.elec_realization < df.elec_realization.quantile(.80)]
#df = df[df.elec_realization.quantile(.20) < df.elec_realization]
#df.elec_realization.hist(figsize=(10,5))

# %%
len(df)
# Out:
# 3

# %% [markdown]
# ###Only include preffered contractors

# %%
#df = df[df.preffered_contractor==1]
#len(df)

# %% [markdown]
# ###Check representativeness across climate zones

# %%
df.climate.value_counts()
# Out:
# 6     1
# 13    1
# 5     1
# dtype: int64

# %% [markdown]
# ###Checking representativeness across features

# %%
df.year_built.hist()

# %% [markdown]
# Remove old (yearbuild<1979) from the sample

# %%
#df = df[df.year_built > 1930]
#df.year_built.hist()

# %%
len(df)
# Out:
# 3

# %%
df.describe()
# Out:
#             zipcode   year_built  pre_conditioned_area  projected_gas_savings  \
# count      3.000000     3.000000              3.000000               3.000000
# mean   92801.666667  1937.333333           1681.333333             275.333333
# std     2493.053817    39.310728            121.083993              94.203680
# min    90047.000000  1908.000000           1552.000000             191.000000
# 25%    91751.000000  1915.000000           1626.000000             224.500000
# 50%    93455.000000  1922.000000           1700.000000             258.000000
# 75%    94179.000000  1952.000000           1746.000000             317.500000
# max    94903.000000  1982.000000           1792.000000             377.000000
#
#        projected_elec_savings  shell_leakage_cfm50_existing  cfm25_pre  \
# count                3.000000                      3.000000          1
# mean              2026.000000                   4612.666667        404
# std               2143.405934                    743.183243        NaN
# min                631.000000                   3982.000000        404
# 25%                792.000000                   4203.000000        404
# 50%                953.000000                   4424.000000        404
# 75%               2723.500000                   4928.000000        404
# max               4494.000000                   5432.000000        404
#
#        foundation_floor_ins_existing  prewall_r  prewin_u  prewin_shgc  \
# count                              0          0         0            0
# mean                             NaN        NaN       NaN          NaN
# std                              NaN        NaN       NaN          NaN
# min                              NaN        NaN       NaN          NaN
# 25%                              NaN        NaN       NaN          NaN
# 50%                              NaN        NaN       NaN          NaN
# 75%                              NaN        NaN       NaN          NaN
# max                              NaN        NaN       NaN          NaN
#
#        gas_furnace_efficiency_existing  cooling_capacity_existing  \
# count                                1                          1
# mean                                75                         14
# std                                NaN                        NaN
# min                                 75                         14
# 25%                                 75                         14
# 50%                                 75                         14
# 75%                                 75                         14
# max                                 75                         14
#
#        shell_leakage_cfm50_new  cfm25_post  window_type_new  postwin_shgc  \
# count                 3.000000     3.00000                0             0
# mean               2184.666667   117.00000              NaN           NaN
# std                1463.284775   100.19481              NaN           NaN
# min                 901.000000    39.00000              NaN           NaN
# 25%                1388.000000    60.50000              NaN           NaN
# 50%                1875.000000    82.00000              NaN           NaN
# 75%                2826.500000   156.00000              NaN           NaN
# max                3778.000000   230.00000              NaN           NaN
#
#        post_afue  cooling_capacity_new  gas_heat
# count          1                     0         3 ...
# mean          95                   NaN         1 ...
# std          NaN                   NaN         0 ...
# min           95                   NaN         1 ...
# 25%           95                   NaN         1 ...
# 50%           95                   NaN         1 ...
# 75%           95                   NaN         1 ...
# max           95                   NaN         1 ...
#
# [8 rows x 66 columns]

# %% [markdown]
# ###Output final files, create a combined file, & create Excel workbook

# %%
df.fillna("")
df.to_csv(dataSelect)

# %%
#Create combined file across climate zones
#df1 = pd.read_csv("/Users/matthewgee/Projects/CalTest/data/final/" + str(util) + "_CalTest_elec_group_1.csv")
#df2 = pd.read_csv("/Users/matthewgee/Projects/CalTest/data/final/" + str(util) + "_CalTest_elec_group_2.csv")
#df3 = pd.read_csv("/Users/matthewgee/Projects/CalTest/data/final/" + str(util) + "_CalTest_elec_group_3.csv")
#df = pd.concat([df1,df2,df3])
#df.to_csv(combinedSelect)
#df.to_excel(combinedSelectX)
