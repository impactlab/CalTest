# %% [markdown]
# #Explore the file generated by reading the XML file

# %%
import pandas as pd

df = pd.read_csv("/Users/matthewgee/Projects/CalTest/data/CalTestCombined_XML_Data.csv")

# %%
df
# Out:
# Unnamed: 0               4970
# Address                   280
# BuildingAddress           283
# BuildingID                288
# BuildingType             4931
# CAZone                   4963
# CeilingHeight            4962
# City                     4829
# Company                  4923
# CondenserType            4962
# ConditionedFloorArea     4963
# CoolingEfficiency        4962
# CoolingHVACType          4962
# DHWType                  4962
# DesignCoolingCapacity    4962
# ...
# Zone1Room1Ins5_FrameType      4808
# Zone1Room1Ins5_JAIVIndex      4808
# Zone1Room1Ins5_Name           4323
# Zone1Room1Ins5_Orientation    4808
# Zone1Room1Ins5_UFactor        4808
# Zone1Room1_CeilingHeight      4953
# Zone1Room1_FloorArea          4953
# Zone1Room1_Name               4395
# Zone1Room1_SummerIDB          4953
# Zone1Room1_WinterIDB          4953
# Zone1Room1_YearBuilt          4953
# Zone_1FloorNo                 4962
# Zone_1ZoneType                4962
# ...
