# %% [markdown]
# #PG&E Portfolio Analysis

# %%
import pandas as pd

#specify dataset
useData = "/Users/matthewgee/Projects/CalTest/data/final/pge_CalTest_data_prepped.csv"

df = pd.read_csv(useData)

# %%
df.dtypes
df.climate.value_counts()
# Out:
# 12    816
# 3     440
# 4     146
# 11     93
# 2      89
# 13     47
# 16      5
# 5       2
# 7       1
# dtype: int64

# %%
df.year_built.hist()

# %%
df.conditionedsqft.hist()

# %%
df.shell_leakage_cfm50_existing.hist()
