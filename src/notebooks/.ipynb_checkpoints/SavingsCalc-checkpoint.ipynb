# %% [markdown]
# ###Weather Normalization and Savings Calculation for
#
# ####Data Requirements
#
# 1. Account-level gas & electricity data for a full year before and after the upgrades
# 2. Date of retrofit to create pre-post split
# 3. Daily weather data to create heating degree days and cooling degree days measures
#
# ####Steps
#
#    1. Clean account level gas and electric data (this is moved to stata for now)
#
#        - Specify id var, use var, and time var
#        - Standardize time variable
#        - Standardize use variable
#           - Monthly total therms for gas
#           - Monthly total kwh for electricity
#        - Create billing period length variable
#        - Generate daily average use per bill period:
#          $\frac{TotalMonthQuantity}{BillPeriod}$
#
#    2. Separate use by pre-post retrofit
#        - Merge in retrofit date from project data
#
#    3. Create measure of heating degree days and cooling degree days for each station/month
#    4. Merge hdd and cdd into use file
#    5. Run regression for prediction
#    6. Get savings for gas & electric as well as R^2

# %%
from __future__ import print_function
import pandas as pd
import numpy as np
import statsmodels.api as sm

###Weather normalization 

scgPath = '/Users/matthewgee/Projects/CalTest/data/scg/final/'
sdgePath = "/Users/matthewgee/Projects/CalTest/Data/sdge/" 

#Consumption Files
consumptionFiles = {
    'sceGas' : "/Users/matthewgee/Projects/CalTest/data/final/sce_gas_prepped.csv",
    'sceElec' : "/Users/matthewgee/Projects/CalTest/data/final/sce_elec_prepped.csv",
    'sdgeGas' : "/Users/matthewgee/Projects/CalTest/data/sdge/final/sdge_gas_prepped.csv",
    'sdgeElec' : "/Users/matthewgee/Projects/CalTest/data/sdge/final/sdge_elec_prepped.csv" }


#Attribute Files
projectFiles = {
    'sce' : "/Users/matthewgee/Projects/CalTest/data/final/sce_project_data_prepped.csv",
    'sdge' : "/Users/matthewgee/Projects/CalTest/data/sdge/final/sdge_project_data_prepped.csv" }

#Linking Files
sdgeLink = 'SDG&E CalTEST home data April2014.csv'
linkvar = 'dnvgl_acct_id'

vars = {
        'sdge':
            {'idvar':'','tempvar':''},
        'scg':
            {}
        }


#weatherData = "/Users/matthewgee/Projects/CalTest/data/weather/cz2010_gsod_2006_2013.csv"
rawWeatherData = "/Users/matthewgee/Projects/CalTest/data/weather/CalTrack_Complete_Temps.csv"
ddWeatherData = "/Users/matthewgee/Projects/CalTest/data/weather/weather_data_prepped.csv"

# %%
#Explore use data

gas = pd.read_csv(consumptionFiles['sceGas'])
gas

elec = pd.read_csv(consumptionFiles['sceElec'])

elec
#elec.METER_READ_END_DATE = pd.to_datetime(elec.METER_READ_END_DATE)
#elec.METER_READ_END_DATE.describe()
# Out:
#    visionnumber\tperiod\ttot_kwh\tolddate\tyr\tbill_start_date\tbill_end_date\tbill_period_length\tgroup\tavg_daily_kwh\tretrofit_date\tca_climate_zone\tzipcode\tpre_conditioned_area\tphase
# 0   SEHDPS1526374739\t0\t540\t"1/8/2008"\t2008\t17...
# 1   SEHDPS1526374739\t1\t427\t"2/6/2008"\t2008\t17...
# 2   SEHDPS1526374739\t2\t442\t"3/7/2008"\t2008\t17...
# 3   SEHDPS1526374739\t3\t428\t"4/8/2008"\t2008\t17...
# 4   SEHDPS1526374739\t4\t485\t"5/7/2008"\t2008\t17...
# 5   SEHDPS1526374739\t5\t440\t"6/6/2008"\t2008\t17...
# 6   SEHDPS1526374739\t6\t902\t"7/9/2008"\t2008\t17...
# 7   SEHDPS1526374739\t7\t671\t"8/7/2008"\t2008\t17...
# 8   SEHDPS1526374739\t8\t663\t"9/8/2008"\t2008\t17...
# 9   SEHDPS1526374739\t9\t500\t"10/6/2008"\t2008\t1...
# 10  SEHDPS1526374739\t10\t364\t"11/6/2008"\t2008\t...
# 11  SEHDPS1526374739\t11\t393\t"12/9/2008"\t2008\t...
# 12  SEHDPS1526374739\t12\t235\t"1/9/2009"\t2009\t1...
# 13  SEHDPS1526374739\t13\t401\t"2/6/2009"\t2009\t1...
# 14  SEHDPS1526374739\t14\t485\t"3/10/2009"\t2009\t...
# 15  SEHDPS1526374739\t15\t369\t"4/9/2009"\t2009\t1...
# 16  SEHDPS1526374739\t16\t455\t"5/11/2009"\t2009\t...
# 17  SEHDPS1526374739\t17\t412\t"6/9/2009"\t2009\t1...
# 18  SEHDPS1526374739\t18\t597\t"7/9/2009"\t2009\t1...
# 19  SEHDPS1526374739\t19\t928\t"8/8/2009"\t2009\t1...
# 20  SEHDPS1526374739\t20\t838\t"9/9/2009"\t2009\t1...
# 21  SEHDPS1526374739\t21\t599\t"10/7/2009"\t2009\t...
# 22  SEHDPS1526374739\t22\t406\t"11/6/2009"\t2009\t...
# 23  SEHDPS1526374739\t23\t497\t"12/10/2009"\t2009\...
# 24  SEHDPS1526374739\t24\t423\t"1/8/2010"\t2010\t1...
# 25  SEHDPS1526374739\t25\t570\t"2/8/2010"\t2010\t1...
# 26  SEHDPS1526374739\t26\t427\t"3/11/2010"\t2010\t...
# 27  SEHDPS1526374739\t27\t410\t"4/9/2010"\t2010\t1...
# 28  SEHDPS1526374739\t28\t422\t"5/10/2010"\t2010\t...
# 29  SEHDPS1526374739\t29\t461\t"6/9/2010"\t2010\t1...
# 30  SEHDPS1526374739\t30\t627\t"7/9/2010"\t2010\t1...
# 31  SEHDPS1526374739\t31\t519\t"8/9/2010"\t2010\t1...
# 32  SEHDPS1526374739\t32\t805\t"9/8/2010"\t2010\t1...
# 33  SEHDPS1526374739\t33\t578\t"10/7/2010"\t2010\t...
# 34  SEHDPS1526374739\t34\t465\t"11/8/2010"\t2010\t...
# 35  SEHDPS1526374739\t35\t500\t"12/9/2010"\t2010\t...
# 36  SEHDPS1526374739\t36\t502\t"1/10/2011"\t2011\t...
# 37  SEHDPS1526374739\t37\t428\t"2/8/2011"\t2011\t1...
# 38  SEHDPS1526374739\t38\t428\t"3/10/2011"\t2011\t...
# 39  SEHDPS1526374739\t39\t373\t"4/8/2011"\t2011\t1...
# 40  SEHDPS1526374739\t40\t411\t"5/9/2011"\t2011\t1...
# 41  SEHDPS1526374739\t41\t374\t"6/8/2011"\t2011\t1...
# 42  SEHDPS1526374739\t42\t644\t"7/8/2011"\t2011\t1...
# 43  SEHDPS1526374739\t43\t745\t"8/8/2011"\t2011\t1...
# 44  SEHDPS1526374739\t44\t632\t"9/7/2011"\t2011\t1...
# 45  SEHDPS1526374739\t45\t453\t"10/6/2011"\t2011\t...
# 46  SEHDPS1526374739\t46\t362\t"11/8/2011"\t2011\t...
# 47  SEHDPS1526374739\t47\t337\t"12/9/2011"\t2011\t...
# 48  SEHDPS1526374739\t48\t404\t"1/10/2012"\t2012\t...
# 49  SEHDPS1526374739\t49\t263\t"2/8/2012"\t2012\t1...
# 50  SEHDPS1526374739\t50\t282\t"3/9/2012"\t2012\t1...
# 51  SEHDPS1526374739\t51\t283\t"4/9/2012"\t2012\t1...
# 52  SEHDPS1526374739\t52\t279\t"5/8/2012"\t2012\t1...
# 53  SEHDPS1526374739\t53\t313\t"6/7/2012"\t2012\t1...
# 54  SEHDPS1526374739\t54\t331\t"7/9/2012"\t2012\t1...
# 55  SEHDPS1526374739\t55\t359\t"8/7/2012"\t2012\t1...
# 56  SEHDPS1526374739\t56\t499\t"9/6/2012"\t2012\t1...
# 57  SEHDPS1526374739\t57\t419\t"10/9/2012"\t2012\t...
# 58  SEHDPS1526374739\t58\t273\t"11/7/2012"\t2012\t...
# 59  SEHDPS1526374739\t59\t354\t"12/10/2012"\t2012\...
#                                                   ...
#
# [35046 rows x 1 columns]

# %%
def formatUseVars(df, datevar):
    """Function for formatting column names to standard 
        Currently depricated because formatting is done during preprocessing
    """
    df[datevar]=pd.to_datetime(df[datevar])
    
    return df

# %%
def ddDailyCalc(useFile,weatherFile):
    """Takes use data and weather data and generates 
    """
    use=pd.read_csv(useFile)
    weather = pd.read_csv(weatherFile)
    
    #c
    merge
    
    return df

# %%
def weatherNormalization(df,usevar,cddvar,hddvar):
    """
    Inputs: PandasDataFrame of raw use data with heading Degree Days
    Outputs: Pandas DataFrame with weather normalized data
    """

# %%
#Create Weather Data Class with hdd anc cdd methods

class Weather(object):
    """Class for weather data 
    ...
    Args
    ----
    location: string
    timeVariable: string
    """
    
    def __init__(self):
        self.stuff = 0

# %%
#Get date of 

def

# %% [markdown]
# hdd = Normalize.hdd('')
# cdd = Normalize.cdd('')

# %%
#Create EnergyData Class with imput and normalize methods
