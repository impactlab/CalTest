# %% [markdown]
# ##CalTest Home Selection Electricity
#
# *The purpose of home selection is to find a reprentative set of homes for CalTest. Representitiveness was determined by the following criteria:*
#
# 1. Contractor (Completed by preferred contractors)
# 2. Pre-retrofit air leakage (25th-90th percentile of CFM50)
# 3. Energy intesity (25th-90th percentile)
# 4. Elec HVAC Unit
# 5. Stories (1)
# 6. Total conditioned area (20th-80th percentile)
# 7. Total electrictiy use (>40th percentile)
# 8. Total elec savings (>40th percentile)
# 9. Electic realization rate (25th-75th percentile)
# 10. Fit on heating degree days regression ($R^2>.9$)
# 11. Year built (>1950)
# 12. Climate grouping (evenly distributed across 3 main groups)
# 13. Utility (representative sample from each IOU)
#
# The final dataset `CalTest_test_homes_v1_4-1.csv` consists of 28 homes that form a representative distribution of home types, climate areas, and measures, while also meeting the selection criteria above.
#
# Test homes are also displayed in the likely format for vendors in the excel spreadsheet `CalTest_beta_v3_April_2.xls`.

# %% [markdown]
# ####Steps in home selection

# %% [markdown]
# Begin with combined dataset of cleaned home charateristics with weather normalized data.
#
#     CalTest_combined_project_data_cleaned.csv
#     CalTest_combined_usage_data_cleaned.csv

# %%
import pandas as pd
import matplotlib as plt


util = "sce"
climategroup = 4

#specify dataset
useData = "/Users/matthewgee/Projects/CalTest/data/final/" + str(util) +"_CalTest_data_prepped.csv"
#useData = "/Users/matthewgee/Projects/CalTest/data/final/SCE_project_info_cleaned.csv"
#specify path
savePath = "/Users/matthewgee/Projects/CalTest/data/final/"


#Define switch class
class switch(object):
    def __init__(self, value):
        self.value = value
        self.fall = False

    def __iter__(self):
        """Return the match method once, then stop"""
        yield self.match
        raise StopIteration
    
    def match(self, *args):
        """Indicate whether or not to enter a case suite"""
        if self.fall or not args:
            return True
        elif self.value in args: # changed for v1.5, see below
            self.fall = True
            return True
        else:
            return False

# %%
#set utility and climate group for run
#loop through scg, sdge pge
#loop throug climate group 1,2,3

#Output filenames
dataSelect = "/Users/matthewgee/Projects/CalTest/data/final/" + str(util) + "_CalTest_elec_group_" + str(climategroup) +".csv"
combinedSelect = "/Users/matthewgee/Projects/CalTest/data/final/" + str(util) + "_combined_CalTest_elec.csv"
combinedSelectX = "/Users/matthewgee/Projects/CalTest/data/final/" + str(util) + "_combined_CalTest_elec.xls"

# %% [markdown]
# ####Read in data as dataframes, and identify homes by utility

# %%
df = pd.read_csv(useData)
len(df)
df
# Out:
#                        contractorcompany  preffered_contractor  \
# 0              SoCal Remodeling Products                     1
# 1              SoCal Remodeling Products                     1
# 2         Zero Energy Contracting , Inc.                   NaN
# 3                              SolarCity                   NaN
# 4               Home Performance Matters                     1
# 5   Alpine Green Property Services, Inc.                   NaN
# 6         Zero Energy Contracting , Inc.                   NaN
# 7         Zero Energy Contracting , Inc.                   NaN
# 8   Alpine Green Property Services, Inc.                   NaN
# 9         Zero Energy Contracting , Inc.                   NaN
# 10        Zero Energy Contracting , Inc.                   NaN
# 11         Wes Harding Construction Inc.                   NaN
# 12               Sequoia Energy Services                   NaN
# 13                             SolarCity                   NaN
# 14         Wes Harding Construction Inc.                   NaN
# 15        Zero Energy Contracting , Inc.                   NaN
# 16              Home Performance Matters                     1
# 17        Zero Energy Contracting , Inc.                   NaN
# 18        Zero Energy Contracting , Inc.                   NaN
# 19              Home Performance Matters                     1
# 20    Progressive Insulation and Windows                     1
# 22    Raised Floor  Natural Gas                Natural Gas
# 23    Raised Floor  Natural Gas                Natural Gas
# 24    Raised Floor  Natural Gas                Natural Gas
# 25   Slab on Grade  Natural Gas                        NaN
# 26    Raised Floor  Natural Gas                Natural Gas
# 27   Slab on Grade  Natural Gas                        NaN
# 28   Slab on Grade  Natural Gas                Natural Gas
# 29    Raised Floor  Natural Gas                Natural Gas
# 30   Slab on Grade  Natural Gas                Natural Gas
# 31   Slab on Grade  Natural Gas                Natural Gas
# 32   Slab on Grade  Natural Gas                Natural Gas
# 33    Raised Floor  Natural Gas                        NaN
# 34   Slab on Grade  Natural Gas                Natural Gas
# 35   Slab on Grade  Natural Gas                Natural Gas
# 36   Slab on Grade  Natural Gas                Natural Gas
# 37    Raised Floor  Natural Gas                Natural Gas
# 38   Slab on Grade  Natural Gas                Natural Gas
# 39   Slab on Grade  Natural Gas                Natural Gas
# 40    Raised Floor  Natural Gas                Natural Gas
# 41    Raised Floor  Natural Gas                Natural Gas
# 42   Slab on Grade  Natural Gas                Natural Gas
# 43   Slab on Grade  Natural Gas                Natural Gas
# 44    Raised Floor  Natural Gas                Natural Gas
# 45   Slab on Grade  Natural Gas                Natural Gas
# 46   Slab on Grade  Natural Gas                Natural Gas
# 47    Raised Floor  Natural Gas                Natural Gas
# 48   Slab on Grade  Natural Gas                Natural Gas
# 49   Slab on Grade  Natural Gas                Natural Gas
# 50    Raised Floor  Natural Gas                Natural Gas
# 51    Raised Floor  Natural Gas                Natural Gas
# 52   Slab on Grade  Natural Gas                Natural Gas
# 53   Slab on Grade  Natural Gas                Natural Gas
# 54   Slab on Grade  Natural Gas                Natural Gas
# 55             NaN          NaN                        NaN
# 56    Raised Floor  Natural Gas                Natural Gas
# 57   Slab on Grade  Natural Gas                Natural Gas
# 58    Raised Floor  Natural Gas                Natural Gas
# 59    Raised Floor  Natural Gas                Natural Gas
#                ...          ...                        ...
#
#                          centralacyesorno  projectedgassavingsthermsyr
# 0                              Central AC                          178 ...
# 1                                     NaN                           92 ...
# 2                              Central AC                          355 ...
# 3                              Central AC                          137 ...
# 4                              Central AC                           88 ...
# 5                    Air Source Heat Pump                           29 ...
# 6                              Central AC                          206 ...
# 7                              Central AC                           60 ...
# 8                            Wall Furnace                          269 ...
# 9                              Central AC                          286 ...
# 10                             Central AC                          NaN ...
# 11                                    NaN                          298 ...
# 12                             Central AC                          288 ...
# 13                             Central AC                          117 ...
# 14                             Central AC                          216 ...
# 15  Wall AC Unit, Central Propane Furnace                          227 ...
# 16                    Central Gas Furnace                          272 ...
# 17                             Central AC                          329 ...
# 18                             Central AC                          264 ...
# 19                                    NaN                          288 ...
# 20                             Central AC                          NaN ...
# 21                             Central AC                          NaN ...
# 22                    Central Gas Furnace                          NaN ...
# 23                             Central AC                          NaN ...
# 24                             Central AC                          NaN ...
# 25                    Central Gas Furnace                          NaN ...
# 26                             Central AC                          NaN ...
# 27                             Central AC                          NaN ...
# 28                             Central AC                          NaN ...
# 29                    Central Gas Furnace                          NaN ...
# 30                             Central AC                          123 ...
# 31                             Central AC                          NaN ...
# 32                             Central AC                          NaN ...
# 33                             Central AC                          NaN ...
# 34                                    NaN                          NaN ...
# 35                             Central AC                          NaN ...
# 36                             Central AC                          NaN ...
# 37                             Central AC                          NaN ...
# 38                             Central AC                          NaN ...
# 39                             Central AC                          NaN ...
# 40                Central HVAC Package DX                          NaN ...
# 41                             Central AC                          448 ...
# 42                Central HVAC Package DX                           72 ...
# 43                             Central AC                          NaN ...
# 44                             Central AC                          NaN ...
# 45                             Central AC                          NaN ...
# 46                             Central AC                          NaN ...
# 47                             Central AC                          NaN ...
# 48                             Central AC                          NaN ...
# 49                             Central AC                          NaN ...
# 50                             Central AC                          NaN ...
# 51                             Central AC                          555 ...
# 52                             Central AC                           50 ...
# 53                           Wall AC Unit                          NaN ...
# 54                             Central AC                          103 ...
# 55                                    NaN                          126 ...
# 56                             Central AC                          227 ...
# 57                             Central AC                           53 ...
# 58                             Central AC                           38 ...
# 59                             Central AC                          178 ...
#                                       ...                          ...
#
# [540 rows x 124 columns]

# %%
#df.elec_realization.describe()
df.climate.value_counts()
# Out:
# 9     387
# 6      47
# 8      42
# 10     34
# 13     23
# 14      7
# dtype: int64

# %% [markdown]
# ###Create climate zone specific datasets

# %%
#Create climate zone-specific datasets
# PG&E (12, 3), (4, 11, 2), (13,16,5,&7) 
# SCE (9), (6,8), (10,13,14,0)
for case in switch(climategroup):
    if case(1):
        df = df[(df['climate']==9)]
        break
    if case(2):
        df = df[(df['climate']==6)]
        break
    if case(3):
        df = df[(df['climate']==8)]
        break
    if case(4):
        df = df[(df['climate']==10)]
        break 
    if case(5):
        df = df[(df['climate']==13)]
        break
    if case():
        print "No climate group"
        break
len(df)
# Out:
# 34

# %% [markdown]
# Subset by climate zone to ensure representativeness

# %% [markdown]
# Subset by contractor (moved to the end of file)

# %%
df.contractor.value_counts()
# Out:
# REEIS CA Inc.                                         13
# Zero Energy Contracting , Inc.                         6
# SoCal Remodeling Products                              4
# The CSI Company                                        4
# Progressive Insulation and Windows                     2
# Residential Energy Assessment Services (REAS), Inc     1
# Cool Air Solutions, Inc.                               1
# Green Homes America LP                                 1
# Home Performance Matters                               1
# SolarCity                                              1
# dtype: int64

# %%
#I no longer screen by contractor size
#g = df.groupby('contractor')
#df = g.filter(lambda x: len(x) > 5)
#df.contractor.value_counts()

# %% [markdown]
# ####Filter by quantile of pre-retrofit CFM50

# %%
df.shell_leakage_cfm50_existing.describe()
# Out:
# count      31.000000
# mean     2865.351613
# std      1372.121195
# min         4.900000
# 25%      2085.000000
# 50%      2611.000000
# 75%      3254.500000
# max      6537.000000
# Name: shell_leakage_cfm50_existing, dtype: float64

# %% [markdown]
# Histogram of pre-retrofi CFM50

# %%
df.shell_leakage_cfm50_existing.hist(figsize=(10,5))

# %% [markdown]
# Remove lower 25% percentile and top 10 percentile of CFM50

# %%
df = df[df.shell_leakage_cfm50_existing < df.shell_leakage_cfm50_existing.quantile(.90)]
df = df[df.shell_leakage_cfm50_existing.quantile(.25) < df.shell_leakage_cfm50_existing]
df.shell_leakage_cfm50_existing.hist(figsize(10,5))

# %% [markdown]
# New distribution of CFM50

# %%
len(df)
# Out:
# 20

# %% [markdown]
# ###Select by energy intensity

# %%
df.energy_intensity_elec.hist(figsize=(10,5))

# %% [markdown]
# Remove lower 25 percentile and top 10 percentile of CFM50

# %%
df = df[df.energy_intensity_elec < df.energy_intensity_elec.quantile(.90)]
df = df[df.energy_intensity_elec.quantile(.25) < df.energy_intensity_elec]
df.energy_intensity_elec.hist(figsize=(10,5))

# %% [markdown]
# ###Must have central AC

# %%
#df= df[df.cooltype1!="None"]
#len(df)

# %% [markdown]
# ###Remove based on number of stories
# For now we are including only 1 story buildings

# %%
#df.stories.value_counts()

# %%
#df = df[df.stories_above_grade==1]
#len(df)

# %% [markdown]
# ###Subset by total area
#
# Look at the distribution of total conditioned area across the subset of homes.

# %%
df.pre_conditioned_area.hist(figsize=(10,5))

# %% [markdown]
# Dropping the lower and upper 20% of the distribution

# %%
df = df[df.pre_conditioned_area < df.pre_conditioned_area.quantile(.80)]
df = df[df.pre_conditioned_area.quantile(.20) < df.pre_conditioned_area]
df.pre_conditioned_area.hist(figsize=(10,5))

# %% [markdown]
# ###Subset on total electricity savings
# We select for the upper 60% and remove only the top 3% from the total realized savings distribution to ensure there is enough signal in the sample homes for testing.

# %%
df.electricity_savings.hist(figsize=(10,5))
len(df)
#df.electricity_savings.hist(figsize=(10,5))
# Out:
# 8

# %%
df = df[df.electricity_savings < df.electricity_savings.quantile(.97)]
df = df[df.electricity_savings.quantile(.40) < df.electricity_savings]
df.electricity_savings.hist(figsize=(10,5))

# %%
len(df)
# Out:
# 4

# %% [markdown]
# ###Subset on Realization Rate
#
# Examining the distribution of realization rates for gas and electricity

# %%
#Gas Realization rates
#df.gas_realization.hist()

# %%
#Electricity Realization rates
df.elec_realization.hist()

# %% [markdown]
# Drop the upper and lower 25th percentiles for both gas and electrcity

# %%
#df = df[df.elec_realization < df.elec_realization.quantile(.80)]
#df = df[df.elec_realization.quantile(.20) < df.elec_realization]
#df.elec_realization.hist(figsize=(10,5))

# %%
len(df)
# Out:
# 4

# %% [markdown]
# ###Only include preffered contractors

# %%
#df = df[df.preffered_contractor==1]
len(df)
# Out:
# 4

# %% [markdown]
# ###Check representativeness across climate zones

# %%
df.climate.value_counts()
# Out:
# 10    4
# dtype: int64

# %% [markdown]
# ###Checking representativeness across features

# %%
#df.year_built.hist()

# %% [markdown]
# Remove old (yearbuild<1979) from the sample

# %%
#df = df[df.year_built > 1930]
#df.year_built.hist()

# %%
len(df)
# Out:
# 4

# %%
df.describe()
# Out:
# 30     123
# 52      50
# 175    285
# 362     68
# Name: projectedgassavingsthermsyr, dtype: float64

# %% [markdown]
# ###Output final files, create a combined file, & create Excel workbook

# %%
df.fillna("")
df.to_csv(dataSelect)

# %%
#Create combined file across climate zones
df1 = pd.read_csv("/Users/matthewgee/Projects/CalTest/data/final/" + str(util) + "_CalTest_elec_group_1.csv")
df2 = pd.read_csv("/Users/matthewgee/Projects/CalTest/data/final/" + str(util) + "_CalTest_elec_group_2.csv")
df3 = pd.read_csv("/Users/matthewgee/Projects/CalTest/data/final/" + str(util) + "_CalTest_elec_group_3.csv")
df4 = pd.read_csv("/Users/matthewgee/Projects/CalTest/data/final/" + str(util) + "_CalTest_elec_group_4.csv")

df = pd.concat([df1,df2,df3,df4])
df.to_csv(combinedSelect)
df.to_excel(combinedSelectX)
