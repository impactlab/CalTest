# %% [markdown]
# ##CalTest Home Selection Electricity
#
# *The purpose of home selection is to find a reprentative set of homes for CalTest. Representitiveness was determined by the following criteria:*
#
# 1. Contractor (Completed by preferred contractors)
# 2. Pre-retrofit air leakage (25th-90th percentile of CFM50)
# 3. Energy intesity (25th-90th percentile)
# 4. Elec HVAC Unit
# 5. Stories (1)
# 6. Total conditioned area (20th-80th percentile)
# 7. Total electrictiy use (>40th percentile)
# 8. Total elec savings (>40th percentile)
# 9. Electic realization rate (25th-75th percentile)
# 10. Fit on heating degree days regression ($R^2>.9$)
# 11. Year built (>1950)
# 12. Climate grouping (evenly distributed across 3 main groups)
# 13. Utility (representative sample from each IOU)
#
# The final dataset `CalTest_test_homes_v1_4-1.csv` consists of 28 homes that form a representative distribution of home types, climate areas, and measures, while also meeting the selection criteria above.
#
# Test homes are also displayed in the likely format for vendors in the excel spreadsheet `CalTest_beta_v3_April_2.xls`.

# %% [markdown]
# ####Steps in home selection

# %% [markdown]
# Begin with combined dataset of cleaned home charateristics with weather normalized data.
#
#     CalTest_combined_project_data_cleaned.csv
#     CalTest_combined_usage_data_cleaned.csv

# %%
import pandas as pd
import matplotlib as plt


util = "scg"
climategroup = 5

#specify dataset
#useData = "/Users/matthewgee/Projects/CalTest/data/final/" + str(util) +"_CalTest_data_prepped.csv"
useData = "/Users/matthewgee/Projects/CalTest/data/final/SCE_project_info_cleaned.csv"
#specify path
savePath = "/Users/matthewgee/Projects/CalTest/data/final/"


#Define switch class
class switch(object):
    def __init__(self, value):
        self.value = value
        self.fall = False

    def __iter__(self):
        """Return the match method once, then stop"""
        yield self.match
        raise StopIteration
    
    def match(self, *args):
        """Indicate whether or not to enter a case suite"""
        if self.fall or not args:
            return True
        elif self.value in args: # changed for v1.5, see below
            self.fall = True
            return True
        else:
            return False

# %%
#set utility and climate group for run
#loop through scg, sdge pge
#loop throug climate group 1,2,3
util = "sce"
climategroup = 5

#Output filenames
dataSelect = "/Users/matthewgee/Projects/CalTest/data/final/" + str(util) + "_CalTest_elec_group_" + str(climategroup) +".csv"
combinedSelect = "/Users/matthewgee/Projects/CalTest/data/final/" + str(util) + "_combined_CalTest_elec.csv"
combinedSelectX = "/Users/matthewgee/Projects/CalTest/data/final/" + str(util) + "_combined_CalTest_elec.xls"

# %% [markdown]
# ####Read in data as dataframes, and identify homes by utility

# %%
df = pd.read_csv(useData)
len(df)
df
# Out:
#                              contractorcompany  preffered_contractor  \
# 0              AZ Air Conditioning and Heating                     1
# 1                             Building Doctors                     1
# 2                      Dennis Allen Associates                     1
# 3                Green Guys Construction, Inc.                     1
# 4                              Greener Fitting                     1
# 5                     Home Performance Matters                     1
# 6                                 IRC Services                     1
# 7   Mediterranean Heating and Air Conditioning                     1
# 8      PROS 360 - Performance Contractor, Inc.                     1
# 9           Progressive Insulation and Windows                     1
# 10                   SoCal Remodeling Products                     1
# 11                Splinters Construction, Inc.                     1
# 12         Tempco Air Conditioning and Heating                     1
# 13      ABC Cooling and Heating Services, Inc.                   NaN
# 14      ABC Cooling and Heating Services, Inc.                   NaN
# 15        Alpine Green Property Services, Inc.                   NaN
# 16        Alpine Green Property Services, Inc.                   NaN
# 17        Alpine Green Property Services, Inc.                   NaN
# 18        Alpine Green Property Services, Inc.                   NaN
# 19        Alpine Green Property Services, Inc.                   NaN
# 20        Alpine Green Property Services, Inc.                   NaN
# 21        Alpine Green Property Services, Inc.                   NaN
# 22        Alpine Green Property Services, Inc.                   NaN
# 23        Alpine Green Property Services, Inc.                   NaN
# 24                 Blain Construction Co. Inc.                   NaN
# 25                 Blain Construction Co. Inc.                   NaN
# 26                 Blain Construction Co. Inc.                   NaN
# 27                 Blain Construction Co. Inc.                   NaN
# 28                            Building Doctors                     1
# 29                            Building Doctors                     1
# 30                            Building Doctors                     1
# 31                            Building Doctors                     1
# 32                            Building Doctors                     1
# 33                            Building Doctors                     1
# 34                            Building Doctors                     1
# 35                            Building Doctors                     1
# 36                            Building Doctors                     1
# 37                            Building Doctors                     1
# 38                            Building Doctors                     1
# 39                            Building Doctors                     1
# 40                            Building Doctors                     1
# 41                            Building Doctors                     1
# 42                            Building Doctors                     1
# 43                            Building Doctors                     1
# 44                            Building Doctors                     1
# 45                            Building Doctors                     1
# 46                            Building Doctors                     1
# 47                            Building Doctors                     1
# 48                            Building Doctors                     1
# 49                            Building Doctors                     1
# 50                            Building Doctors                     1
# 51                            Building Doctors                     1
# 52                            Building Doctors                     1
# 53                            Building Doctors                     1
# 54                            Building Doctors                     1
# 55                            Building Doctors                     1
# 56                            Building Doctors                     1
# 57                            Building Doctors                     1
# 58                            Building Doctors                     1
# 59       California Replacement  Windows, Inc.                   NaN
#                                            ...                   ...
#
#               siteid     audit_date retrofit_date retrofit_complete_date  \
# 0                NaN            NaN           NaN                    NaN
# 1   SEHDPS1526388278       9/1/2011     10jan2012              1/10/2012
# 2   SEHDPS1526388239       8/2/2011     09dec2011              12/9/2011
# 3                NaN            NaN           NaN                    NaN
# 4   SEHDPS1526388663      2/21/2012     17jul2012              7/17/2012
# 5   SEHDPS1526388147      4/18/2011     07feb2012               2/7/2012
# 6                NaN            NaN           NaN                    NaN
# 7                NaN            NaN           NaN                    NaN
# 8   SEHDPS1526388840       6/4/2012     19sep2012              9/19/2012
# 9   SEHDPS1526388226      7/13/2011     11oct2011             10/11/2011
# 10  SEHDPS1526382282       4/6/2012     20jun2012              6/20/2012
# 11  SEHDPS1526388676       3/2/2012     26jun2012              6/26/2012
# 12  SEHDPS1526388443     11/17/2011     01mar2012               3/1/2012
# 13  SEHDPS1526388784       5/1/2012     05sep2012               9/5/2012
# 14  SEHDPS1526388479     11/29/2011     03may2012               5/3/2012
# 15  SEHDPS1526388552       1/3/2012     02aug2012               8/2/2012
# 16  SEHDPS1526388290      9/10/2011     13feb2012              2/13/2012
# 17  SEHDPS1526383812      1/18/2012     25jul2012              7/25/2012
# 18  SEHDPS1526388246      8/12/2011     05mar2012               3/5/2012
# 19  SEHDPS1526388719      3/30/2012     02aug2012               8/2/2012
# 20  SEHDPS1526383808      9/20/2011     02may2012               5/2/2012
# 21  SEHDPS1526388643      2/10/2012     09sep2012               9/9/2012
# 22  SEHDPS1526388535     12/27/2011     27apr2012              4/27/2012
# 23  SEHDPS1526388232      7/26/2011     17jan2012              1/17/2012
# 24  SEHDPS1526388655      2/16/2012     23apr2012              4/23/2012
# 25  SEHDPS1526388781       5/1/2012     13jul2012              7/13/2012
# 26  SEHDPS1526388589      1/17/2012     15mar2012              3/15/2012
# 48                        NaN              Central AC
# 49                Natural Gas              Central AC
# 50                Natural Gas                     NaN
# 51                Natural Gas     Central Gas Furnace
# 52                Natural Gas  Central AC, Other Heat
# 53                Natural Gas                     NaN
# 54                Natural Gas              Central AC
# 55                Natural Gas              Central AC
# 56                Natural Gas            Wall AC Unit
# 57                        NaN              Central AC
# 58                Natural Gas              Central AC
# 59                Natural Gas                     NaN
#                           ...                     ...
#
#     projectedgassavingsthermsyr  projectedelectricsavingskwh
# 0                           NaN                          NaN ...
# 1                           107                         3756 ...
# 2                           238                          180 ...
# 3                           NaN                          NaN ...
# 4                            65                         2404 ...
# 5                            48                         1252 ...
# 6                           NaN                          NaN ...
# 7                           NaN                          NaN ...
# 8                           254                         5575 ...
# 9                           197                         2850 ...
# 10                           92                         1840 ...
# 11                          347                         4968 ...
# 12                           61                         1305 ...
# 13                          255                         4962 ...
# 14                          486                        12788 ...
# 15                          202                         4931 ...
# 16                           60                         1350 ...
# 17                          269                         -975 ...
# 18                           83                         2952 ...
# 19                          291                        -2355 ...
# 20                           29                         7158 ...
# 21                          239                         2985 ...
# 22                          194                         2355 ...
# 23                          111                          113 ...
# 24                          309                         7881 ...
# 25                          270                         3404 ...
# 26                           75                         1055 ...
# 27                           27                          765 ...
# 28                          163                        -1220 ...
# 29                          245                         3084 ...
# 30                          NaN                          NaN ...
# 31                          152                         1489 ...
# 32                          419                         -359 ...
# 33                          210                          299 ...
# 34                          NaN                          NaN ...
# 35                          NaN                          NaN ...
# 36                          169                         2038 ...
# 37                          286                         1947 ...
# 38                          NaN                          NaN ...
# 39                          340                          473 ...
# 40                          112                          127 ...
# 41                          305                         1033 ...
# 42                          133                         -116 ...
# 43                          NaN                          NaN ...
# 44                          326                          770 ...
# 45                          161                         2625 ...
# 46                          177                         4015 ...
# 47                          NaN                          NaN ...
# 48                          200                         1317 ...
# 49                          104                         2111 ...
# 50                          119                           75 ...
# 51                          169                          254 ...
# 52                          135                          142 ...
# 53                          144                          692 ...
# 54                          197                         2600 ...
# 55                          NaN                          NaN ...
# 56                          199                          205 ...
# 57                          140                         1992 ...
# 58                          NaN                          NaN ...
# 59                          178                          396 ...
#                             ...                          ...
#
# [605 rows x 106 columns]

# %%
df.elec_realization.describe()
df.climate.value_counts()
# Out:
# 9     435
# 6      51
# 8      45
# 10     36
# 13     26
# 14      7
# 0       1
# dtype: int64

# %% [markdown]
# ###Create climate zone specific datasets

# %%
#Create climate zone-specific datasets
# PG&E (12, 3), (4, 11, 2), (13,16,5,&7) 
# SCE (9), (6,8), (10,13,14,0)
for case in switch(climategroup):
    if case(1):
        df = df[(df['climate']==12) | (df['climate']==3)]
        df = df[df.preffered_contractor==1]
        break
    if case(2):
        df = df[(df['climate']==11) | (df['climate']==2) | (df['climate']==4)]
        df= df[df.cooltype1!="None"]
        break
    if case(3):
        df = df[(df['climate']==13) | (df['climate']==16) | (df['climate']==5) | (df['climate']==7)]
        df= df[df.cooltype1!="None"]
        break
    if case(4):
        df = df[(df['climate']==9)]
        break 
    if case(5):
        df = df[(df['climate']==12) | (df['climate']==3)]
        break
    if case(6):
        df = df[(df['climate']==13) | (df['climate']==16) | (df['climate']==5) | (df['climate']==7)]
        break
    if case():
        print "No climate group"
        break
len(df)
# Out:
# 0

# %% [markdown]
# Subset by climate zone to ensure representativeness

# %% [markdown]
# Subset by contractor (moved to the end of file)

# %%
df.contractor.value_counts()
# Out:
# Series([], dtype: int64)

# %%
#I no longer screen by contractor size
#g = df.groupby('contractor')
#df = g.filter(lambda x: len(x) > 5)
#df.contractor.value_counts()

# %%
#df = df[df.preffered_contractor==1]
#len(df)

# %% [markdown]
# ####Filter by quantile of pre-retrofit CFM50

# %%
df.shell_leakage_cfm50_existing.describe()
# Out:
# count     383.000000
# mean     3064.801044
# std      1639.252098
# min         0.000000
# 25%      2157.500000
# 50%      2880.000000
# 75%      3810.000000
# max      9500.000000
# Name: shell_leakage_cfm50_existing, dtype: float64

# %% [markdown]
# Histogram of pre-retrofi CFM50

# %%
df.shell_leakage_cfm50_existing.hist(figsize=(10,5))

# %% [markdown]
# Remove lower 25% percentile and top 10 percentile of CFM50

# %%
df = df[df.shell_leakage_cfm50_existing < df.shell_leakage_cfm50_existing.quantile(.90)]
df = df[df.shell_leakage_cfm50_existing.quantile(.25) < df.shell_leakage_cfm50_existing]
df.shell_leakage_cfm50_existing.hist(figsize(10,5))

# %% [markdown]
# New distribution of CFM50

# %%
len(df)
# Out:
# 258

# %% [markdown]
# ###Select by energy intensity

# %%
df.energy_intensity.hist(figsize=(10,5))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-bed63fce94a0> in <module>()
# ----> 1 df.energy_intensity.hist(figsize=(10,5))
#
# /Users/matthewgee/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/tools/plotting.pyc in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, **kwds)
#    2144         values = self.dropna().values
#    2145
# -> 2146         ax.hist(values, **kwds)
#    2147         ax.grid(grid)
#    2148         axes = np.array([ax])
#
# /Users/matthewgee/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    8310             xmax = -np.inf
#    8311             for xi in x:
# -> 8312                 xmin = min(xmin, xi.min())
#    8313                 xmax = max(xmax, xi.max())
#    8314             bin_range = (xmin, xmax)
#
# /Users/matthewgee/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/numpy/core/_methods.pyc in _amin(a, axis, out, keepdims)
#      19 def _amin(a, axis=None, out=None, keepdims=False):
#      20     return um.minimum.reduce(a, axis=axis,
# ---> 21                             out=out, keepdims=keepdims)
#      22
#      23 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
#
# ValueError: zero-size array to reduction operation minimum which has no identity
# /Users/matthewgee/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/axes.py:8261: UserWarning: 2D hist input should be nsamples x nvariables;
#  this looks transposed (shape is 0 x 1)
#   'this looks transposed (shape is %d x %d)' % x.shape[::-1])

# %% [markdown]
# Remove lower 25 percentile and top 10 percentile of CFM50

# %%
#df = df[df.energy_intensity < df.energy_intensity.quantile(.90)]
#df = df[df.energy_intensity.quantile(.25) < df.energy_intensity]
#df.energy_intensity.hist(figsize=(10,5))

# %% [markdown]
# ###Must have central AC

# %%
df= df[df.cooltype1!="None"]
len(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-ebd7a3f26b49> in <module>()
# ----> 1 df= df[df.cooltype1!="None"]
#       2 len(df)
#
# /Users/matthewgee/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    1813                 return self[name]
#    1814             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1815                                  (type(self).__name__, name))
#    1816
#    1817     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'cooltype1'

# %% [markdown]
# ###Remove based on number of stories
# For now we are including only 1 story buildings

# %%
df.stories_above_grade.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-c24695ae5c3b> in <module>()
# ----> 1 df.stories_above_grade.value_counts()
#
# /Users/matthewgee/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    1813                 return self[name]
#    1814             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1815                                  (type(self).__name__, name))
#    1816
#    1817     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'stories_above_grade'

# %%
df = df[df.stories_above_grade==1]
len(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-e6011adf819c> in <module>()
# ----> 1 df = df[df.stories_above_grade==1]
#       2 len(df)
#
# /Users/matthewgee/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    1813                 return self[name]
#    1814             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1815                                  (type(self).__name__, name))
#    1816
#    1817     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'stories_above_grade'

# %% [markdown]
# ###Subset by total area
#
# Look at the distribution of total conditioned area across the subset of homes.

# %%
df.pre_conditioned_area.hist(figsize=(10,5))

# %% [markdown]
# Dropping the lower and upper 20% of the distribution

# %%
df = df[df.pre_conditioned_area < df.pre_conditioned_area.quantile(.80)]
df = df[df.pre_conditioned_area.quantile(.20) < df.pre_conditioned_area]
df.pre_conditioned_area.hist(figsize=(10,5))

# %% [markdown]
# ###Subset on total electricity savings
# We select for the upper 60% and remove only the top 3% from the total realized savings distribution to ensure there is enough signal in the sample homes for testing.

# %%
df.electricity_savings.hist(figsize=(10,5))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-580455e42f5d> in <module>()
# ----> 1 df.electricity_savings.hist(figsize=(10,5))
#
# /Users/matthewgee/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/tools/plotting.pyc in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, **kwds)
#    2144         values = self.dropna().values
#    2145
# -> 2146         ax.hist(values, **kwds)
#    2147         ax.grid(grid)
#    2148         axes = np.array([ax])
#
# /Users/matthewgee/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    8310             xmax = -np.inf
#    8311             for xi in x:
# -> 8312                 xmin = min(xmin, xi.min())
#    8313                 xmax = max(xmax, xi.max())
#    8314             bin_range = (xmin, xmax)
#
# /Users/matthewgee/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/numpy/core/_methods.pyc in _amin(a, axis, out, keepdims)
#      19 def _amin(a, axis=None, out=None, keepdims=False):
#      20     return um.minimum.reduce(a, axis=axis,
# ---> 21                             out=out, keepdims=keepdims)
#      22
#      23 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
df = df[df.electricity_savings < df.electricity_savings.quantile(.97)]
df = df[df.electricity_savings.quantile(.40) < df.electricity_savings]
df.electricity_savings.hist(figsize=(10,5))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-5cc7f0815054> in <module>()
#       1 df = df[df.electricity_savings < df.electricity_savings.quantile(.97)]
#       2 df = df[df.electricity_savings.quantile(.40) < df.electricity_savings]
# ----> 3 df.electricity_savings.hist(figsize=(10,5))
#
# /Users/matthewgee/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/tools/plotting.pyc in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, **kwds)
#    2144         values = self.dropna().values
#    2145
# -> 2146         ax.hist(values, **kwds)
#    2147         ax.grid(grid)
#    2148         axes = np.array([ax])
#
# /Users/matthewgee/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    8310             xmax = -np.inf
#    8311             for xi in x:
# -> 8312                 xmin = min(xmin, xi.min())
#    8313                 xmax = max(xmax, xi.max())
#    8314             bin_range = (xmin, xmax)
#
# /Users/matthewgee/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/numpy/core/_methods.pyc in _amin(a, axis, out, keepdims)
#      19 def _amin(a, axis=None, out=None, keepdims=False):
#      20     return um.minimum.reduce(a, axis=axis,
# ---> 21                             out=out, keepdims=keepdims)
#      22
#      23 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
len(df)
# Out:
# 0

# %% [markdown]
# ###Subset on Realization Rate
#
# Examining the distribution of realization rates for gas and electricity

# %%
#Gas Realization rates
df.gas_realization.hist()

# %%
#Electricity Realization rates
df.elec_realization.hist()

# %% [markdown]
# Drop the upper and lower 25th percentiles for both gas and electrcity

# %%
df = df[df.elec_realization < df.elec_realization.quantile(.80)]
df = df[df.elec_realization.quantile(.20) < df.elec_realization]
df.elec_realization.hist(figsize=(10,5))

# %%
#df = df[df.elec_realization < df.elec_realization.quantile(.80)]
#df = df[df.elec_realization.quantile(.20) < df.elec_realization]
#df.elec_realization.hist(figsize=(10,5))

# %%
len(df)
# Out:
# 163

# %% [markdown]
# ###Only include preffered contractors

# %%
#df = df[df.preffered_contractor==1]
#len(df)

# %% [markdown]
# ###Check representativeness across climate zones

# %%
df.climate.value_counts()
# Out:
# 6     1
# 13    1
# 5     1
# dtype: int64

# %% [markdown]
# ###Checking representativeness across features

# %%
df.year_built.hist()

# %% [markdown]
# Remove old (yearbuild<1979) from the sample

# %%
#df = df[df.year_built > 1930]
#df.year_built.hist()

# %%
len(df)
# Out:
# 3

# %%
df.describe()
# Out:
#             zipcode   year_built  pre_conditioned_area  projected_gas_savings  \
# count      3.000000     3.000000              3.000000               3.000000
# mean   92801.666667  1937.333333           1681.333333             275.333333
# std     2493.053817    39.310728            121.083993              94.203680
# min    90047.000000  1908.000000           1552.000000             191.000000
# 25%    91751.000000  1915.000000           1626.000000             224.500000
# 50%    93455.000000  1922.000000           1700.000000             258.000000
# 75%    94179.000000  1952.000000           1746.000000             317.500000
# max    94903.000000  1982.000000           1792.000000             377.000000
#
#        projected_elec_savings  shell_leakage_cfm50_existing  cfm25_pre  \
# count                3.000000                      3.000000          1
# mean              2026.000000                   4612.666667        404
# std               2143.405934                    743.183243        NaN
# min                631.000000                   3982.000000        404
# 25%                792.000000                   4203.000000        404
# 50%                953.000000                   4424.000000        404
# 75%               2723.500000                   4928.000000        404
# max               4494.000000                   5432.000000        404
#
#        foundation_floor_ins_existing  prewall_r  prewin_u  prewin_shgc  \
# count                              0          0         0            0
# mean                             NaN        NaN       NaN          NaN
# std                              NaN        NaN       NaN          NaN
# min                              NaN        NaN       NaN          NaN
# 25%                              NaN        NaN       NaN          NaN
# 50%                              NaN        NaN       NaN          NaN
# 75%                              NaN        NaN       NaN          NaN
# max                              NaN        NaN       NaN          NaN
#
#        gas_furnace_efficiency_existing  cooling_capacity_existing  \
# count                                1                          1
# mean                                75                         14
# std                                NaN                        NaN
# min                                 75                         14
# 25%                                 75                         14
# 50%                                 75                         14
# 75%                                 75                         14
# max                                 75                         14
#
#        shell_leakage_cfm50_new  cfm25_post  window_type_new  postwin_shgc  \
# count                 3.000000     3.00000                0             0
# mean               2184.666667   117.00000              NaN           NaN
# std                1463.284775   100.19481              NaN           NaN
# min                 901.000000    39.00000              NaN           NaN
# 25%                1388.000000    60.50000              NaN           NaN
# 50%                1875.000000    82.00000              NaN           NaN
# 75%                2826.500000   156.00000              NaN           NaN
# max                3778.000000   230.00000              NaN           NaN
#
#        post_afue  cooling_capacity_new  gas_heat
# count          1                     0         3 ...
# mean          95                   NaN         1 ...
# std          NaN                   NaN         0 ...
# min           95                   NaN         1 ...
# 25%           95                   NaN         1 ...
# 50%           95                   NaN         1 ...
# 75%           95                   NaN         1 ...
# max           95                   NaN         1 ...
#
# [8 rows x 66 columns]

# %% [markdown]
# ###Output final files, create a combined file, & create Excel workbook

# %%
df.fillna("")
df.to_csv(dataSelect)

# %%
#Create combined file across climate zones
#df1 = pd.read_csv("/Users/matthewgee/Projects/CalTest/data/final/" + str(util) + "_CalTest_elec_group_1.csv")
#df2 = pd.read_csv("/Users/matthewgee/Projects/CalTest/data/final/" + str(util) + "_CalTest_elec_group_2.csv")
#df3 = pd.read_csv("/Users/matthewgee/Projects/CalTest/data/final/" + str(util) + "_CalTest_elec_group_3.csv")
#df = pd.concat([df1,df2,df3])
#df.to_csv(combinedSelect)
#df.to_excel(combinedSelectX)
