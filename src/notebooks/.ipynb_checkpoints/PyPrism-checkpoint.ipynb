# %% [markdown]
# #PyPRISM: An open-source version of the Princeton Scorekeeping Method in Python
#
# Author: Matthew Gee
# Version: 0.1
# Date: May 10, 2014
#
# Contains the following classes and methods:
# PyPrism.Weather.get_hdd(balancepoint)
#
# default
# HDD 60
# CDD 65
#
# ##pyprism.clean_weather()
#
# ##pyprism.clean_use()
#
# Returns: A formatted dataframe with standardized column names
#
# ##pyprism.normalize
# Normalize takes data from a single
# Inputs:
#
#
#
# ##pyprism.bulknormalize
# Bulk normalize takes
#
# Inputs:
# usedf: A pre-processed pandas dataframe that contains use data from multiple homes
#
#
# normalize returns
#
# pyprism pass in the balance point temp

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf


#load data
combinedGas = "/Users/matthewgee/Projects/CalTest/data/combined/CalTest_combined_gas_data.csv"
combinedElec = "/Users/matthewgee/Projects/CalTest/data/combined/CalTest_combined_elec_data.csv"
combinedXML = "/Users/matthewgee/Projects/CalTest/data/CalTestCombined_XML_Data.csv"
combinedProjectData = "/Users/matthewgee/Projects/CalTest/data/selected/CalTest_selected_homes_combined_clean.csv"
weather = "/Users/matthewgee/Projects/CalTest/data/weather/weather_data_prepped.csv"

# %%
def clean_use(df,usevar,datevar,end=True,basedate):
    """Convert raw use data to necessary format for normalization
    Inputs:
    usevar: 
            format: total monthly bills
    Input formats
    
    """
    #reformat variable names
    df.rename(columns={usevar:'use',datevar:'date'})
    
    try:
        df.date = df.date.to_datetime
    except:
        print "Unable to convert date to datetime. Try reformating."
        exit()
        
    #generate length of billing period
    if end:
        df['bill_period_length'] = df['date']
    else:
    #return useperday, binary for base period, 
    
    return none

def clean_weather(df, datevar, tempvar):
    """Converts the string to the stuff
    
    """

def ddcreate(weatherdf, hddbp=60, cddbp=65):
    
def stationmatch():
    """
    """
def useddjoin(usedf,dddf,joinvar='date'):
    df = pd.merge(usedf, dddf, on=['date',])
    return df

def normalize(usedf, usevar, basevar="base", hddvar="hdd",cddvar="cdd",hddonly=False,cddonly=False):
    """Normalize takes use data and 
    """
    df = usedf
    
    model = smf.ols(formula= usevar + ' ~ ' hddvar + ' + ' + cddvar, data=df)
    est = model.fit()
    
    pred = model.predict
    
    results = sm.OLS.from_formula('useperday ~ hdd + cdd')
    
    predictions = sm.OLS.predict
    df['r_value'] = res.r
    
    return df

def savings

# %%
pd.merge?
