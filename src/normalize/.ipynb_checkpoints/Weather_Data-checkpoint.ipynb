# %% [markdown]
# ##Prepare Weather Data

# %%
__author__="Matthew Gee"
import pandas as pd
import statsmodels.api as sm

raw_weather = "/Users/matthewgee/Projects/CalTest/data/weather/CalTrack_Complete_Temps.csv"

# %%
class WeatherSettings():
    """This class contains settings used in weather and PRISM
    """
    hdd_ref_temps = range(40,81)
    cdd_ref_temps = range(60,81)
    wu = False
    
    def __init__(self,hdd_ref_temps=range(40,81),cdd_ref_temps=range(60,81),wu=False,namedict={'usaf':'station_number', 'temps':'tempurature','date':'date','CliZn':'climate_zone','Lat':'lat','Lon':'long','Elevation':'elevation'}):
        
        self.hdd_ref_temps = hdd_ref_temps
        self.cdd_ref_temps = cdd_ref_temps
        self.namedict = namedict
        self.wu = wu
        pass
    
    
class WeatherData():
    """This class contains the logic for pulling and preparing weather data for PRISM given
        a weather dataset, and degree day settings object
    
    """
    data_set = ""
    impute = None
    hdd = None
    cdd = None
    hdd_ref_temps = range(55,65)
    cdd_ref_temps = range(65,75)
    wu = False
    wu_key="6bc1ff4991cf0aeb"
    
    def __init__(self,weather_data_set_name,weather_settings):
        
        self.data_set = weather_data_set_name
        self.hdd_ref_temps = weather_settings.hdd_ref_temps
        self.cdd_ref_temps = weather_settings.cdd_ref_temps
        
        if weather_settings.wu:
            self.data = self.get_weather_data(weather_settings)
        else:
            self.data = pd.read_csv(self.data_set)
        pass
        
        #clean and prepare data
        self.data = self.prepare(self.data, weather_settings.namedict)
        
        self.hdd = self.create_hdd_dataset(self.data,weather_settings)
        self.cdd = self.create_cdd_dataset(self.data,weather_settings)
        #self.normals = self.create_normals_dataset(self.hdd,self.cdd,weather_settings)
    
    @staticmethod
    def get_weather_data():
        return 0
    
    @staticmethod    
    def imput():
        return 0
    
    @staticmethod
    def prepare(weather_data, namedict={'usaf':'station_number', 'temps':'tempurature','date':'date','CliZn':'climate_zone','Lat':'lat','Lon':'long','Elevation':'elevation'}):
        """Takes a raw weather dataset and renames columns to standard column names
        
        standardized column names are:
        station_number, station_name, date, tempurature, climate_zone, long, lat, elevation
        """
        
        #rename columns to standard names
        weather_data = weather_data.rename(columns=namedict)
        
        #check date is pandas datetime
        weather_data['date']= pd.to_datetime(weather_data['date'])
        
        #set date as index
        weather_data = weather_data.set_index([weather_data['date']])
        
        return weather_data
        
    @staticmethod
    def create_long_run_averages(weather_data,weather_settings):
        """Takes a dataframe of daily weather data by stations and returns longrun daily average
        
        """
        
        
        weather_data.date = pd.to_datetime(weather_data.date)

        #weather_lra_hdd = weather_data.groupby([weather_data['station_number'],weather_data.index.month,weather_data.index.day]).tempurature.mean()
        weather_lra_hdd = weather_data.groupby([weather_data['station_number'],weather_data.index.month,weather_data.index.day]).tempurature.mean()
        
        weather_lra_cdd
        
        #combine to make normals
        
        return weather_lra_hdd, weather_lra_cdd
    
    @staticmethod
    def create_hdd_dataset(weather_data,weather_settings):
        """Creates a new dataframe of cumulative heating degree days over period for a variety of reference tempuratures
        """
        
        #create a dataset of cumulative heated degree days
        #hdd = weather_data['station_number'].groupby('station_number')
        
        for hdd_ref_temp in weather_settings.hdd_ref_temps:
            weather_data['hdd'] = hdd_ref_temp - weather_data['tempurature']
            weather_data['hdd'] = weather_data['hdd'].apply(lambda x: 0 if x<0 else x)
            #create cumulative total
            #weather_data.index(['station_number','date'])
            #weather_data.sort(['station_number','date'])
            colname = 'hdd' + str(hdd_ref_temp)
            #hdd[colname] = weather_data.groupby(['station_number']).hdd.cumsum()
            
        return weather_data
        
    @staticmethod
    def create_cdd_dataset(weather_data,weather_settings):
        
        return 0
    @staticmethod
    def save_to_database():
        return 0

# %%
weather_settings_test = WeatherSettings()
test = WeatherData(raw_weather,weather_settings_test)

# %%
test.hdd_ref_temps
test.cdd_ref_temps
test.create_hdd_dataset(test.data,weather_settings_test)

# %%
test.data
# Out:
#             station_number       date  tempurature  WthrStationNum  \
# date
# 2006-01-01          690150 2006-01-01         54.8          690150
# 2006-01-02          690150 2006-01-02         58.2          690150
# 2006-01-03          690150 2006-01-03         53.4          690150
# 2006-01-04          690150 2006-01-04         53.8          690150
# 2006-01-05          690150 2006-01-05         58.1          690150
# 2006-01-06          690150 2006-01-06         56.8          690150
# 2006-01-07          690150 2006-01-07         56.4          690150
# 2006-01-08          690150 2006-01-08         57.4          690150
# 2006-01-09          690150 2006-01-09         53.9          690150
# 2006-01-10          690150 2006-01-10         49.8          690150
# 2006-01-11          690150 2006-01-11         49.5          690150
# 2006-01-12          690150 2006-01-12         55.5          690150
# 2006-01-13          690150 2006-01-13         52.7          690150
# 2006-01-14          690150 2006-01-14         57.1          690150
# 2006-01-15          690150 2006-01-15         52.3          690150
# 2006-01-16          690150 2006-01-16         46.5          690150
# 2006-01-17          690150 2006-01-17         48.9          690150
# 2006-01-18          690150 2006-01-18         52.3          690150
# 2006-01-19          690150 2006-01-19         53.1          690150
# 2006-01-20          690150 2006-01-20         46.9          690150
# 2006-01-21          690150 2006-01-21         47.3          690150
# 2006-01-22          690150 2006-01-22         49.5          690150
# 2006-01-23          690150 2006-01-23         50.9          690150
# 2006-01-24          690150 2006-01-24         54.4          690150
# 2006-01-25          690150 2006-01-25         53.2          690150
# 2006-01-26          690150 2006-01-26         53.5          690150
# 2006-01-27          690150 2006-01-27         53.8          690150
# 2006-01-28          690150 2006-01-28         51.4          690150
# 2006-01-29          690150 2006-01-29         56.3          690150
# 2006-01-30          690150 2006-01-30         56.5          690150
# 2006-01-31          690150 2006-01-31         58.3          690150
# 2006-02-01          690150 2006-02-01         59.5          690150
# 2006-02-02          690150 2006-02-02         65.6          690150
# 2006-02-03          690150 2006-02-03         63.7          690150
# 2006-02-04          690150 2006-02-04         61.2          690150
# 2006-02-05          690150 2006-02-05         64.7          690150
# 2006-02-06          690150 2006-02-06         56.8          690150
# 2006-02-07          690150 2006-02-07         55.1          690150
# 2006-02-08          690150 2006-02-08         63.0          690150
# 2006-02-09          690150 2006-02-09         65.1          690150
# 2006-02-10          690150 2006-02-10         64.5          690150
# 2006-02-11          690150 2006-02-11         62.0          690150
# 2006-02-12          690150 2006-02-12         60.8          690150
# 2006-02-13          690150 2006-02-13         63.4          690150
# 2006-02-14          690150 2006-02-14         60.5          690150
# 2006-02-15          690150 2006-02-15         59.4          690150
# 2006-02-16          690150 2006-02-16         47.7          690150
# 2006-02-17          690150 2006-02-17         47.5          690150
# 2006-02-18          690150 2006-02-18         50.6          690150
# 2006-02-19          690150 2006-02-19         48.9          690150
# 2006-02-20          690150 2006-02-20         47.4          690150
# 2006-02-21          690150 2006-02-21         48.2          690150
# 2006-02-22          690150 2006-02-22         52.1          690150
# 2006-02-23          690150 2006-02-23         57.0          690150
# 2006-02-24          690150 2006-02-24         60.6          690150
# 2006-02-25          690150 2006-02-25         60.4          690150
# 2006-02-26          690150 2006-02-26         64.8          690150
# 2006-02-27          690150 2006-02-27         63.4          690150
# 2006-02-28          690150 2006-02-28         65.3          690150
# 2006-03-01          690150 2006-03-01         58.8          690150
#                        ...        ...          ...             ...
#
#             climate_zone    lat    long  elevation
# date
# 2006-01-01            14  34.28 -116.17      55.77
# 2006-01-02            14  34.28 -116.17      55.77
# 2006-01-03            14  34.28 -116.17      55.77
# 2006-01-04            14  34.28 -116.17      55.77
# 2006-01-05            14  34.28 -116.17      55.77
# 2006-01-06            14  34.28 -116.17      55.77
# 2006-01-07            14  34.28 -116.17      55.77
# 2006-01-08            14  34.28 -116.17      55.77
# 2006-01-09            14  34.28 -116.17      55.77
# 2006-01-10            14  34.28 -116.17      55.77
# 2006-01-11            14  34.28 -116.17      55.77
# 2006-01-12            14  34.28 -116.17      55.77
# 2006-01-13            14  34.28 -116.17      55.77
# 2006-01-14            14  34.28 -116.17      55.77
# 2006-01-15            14  34.28 -116.17      55.77
# 2006-01-16            14  34.28 -116.17      55.77
# 2006-01-17            14  34.28 -116.17      55.77
# 2006-01-18            14  34.28 -116.17      55.77
# 2006-01-19            14  34.28 -116.17      55.77
# 2006-01-20            14  34.28 -116.17      55.77
# 2006-01-21            14  34.28 -116.17      55.77
# 2006-01-22            14  34.28 -116.17      55.77
# 2006-01-23            14  34.28 -116.17      55.77
# 2006-01-24            14  34.28 -116.17      55.77
# 2006-01-25            14  34.28 -116.17      55.77
# 2006-01-26            14  34.28 -116.17      55.77
# 2006-01-27            14  34.28 -116.17      55.77
# 2006-01-28            14  34.28 -116.17      55.77
# 2006-01-29            14  34.28 -116.17      55.77
# 2006-01-30            14  34.28 -116.17      55.77
# 2006-01-31            14  34.28 -116.17      55.77
# 2006-02-01            14  34.28 -116.17      55.77
# 2006-02-02            14  34.28 -116.17      55.77
# 2006-02-03            14  34.28 -116.17      55.77
# 2006-02-04            14  34.28 -116.17      55.77
# 2006-02-05            14  34.28 -116.17      55.77
# 2006-02-06            14  34.28 -116.17      55.77
# 2006-02-07            14  34.28 -116.17      55.77
# 2006-02-08            14  34.28 -116.17      55.77
# 2006-02-09            14  34.28 -116.17      55.77
# 2006-02-10            14  34.28 -116.17      55.77
# 2006-02-11            14  34.28 -116.17      55.77
# 2006-02-12            14  34.28 -116.17      55.77
# 2006-02-13            14  34.28 -116.17      55.77
# 2006-02-14            14  34.28 -116.17      55.77
# 2006-02-15            14  34.28 -116.17      55.77
# 2006-02-16            14  34.28 -116.17      55.77
# 2006-02-17            14  34.28 -116.17      55.77
# 2006-02-18            14  34.28 -116.17      55.77
# 2006-02-19            14  34.28 -116.17      55.77
# 2006-02-20            14  34.28 -116.17      55.77
# 2006-02-21            14  34.28 -116.17      55.77
# 2006-02-22            14  34.28 -116.17      55.77
# 2006-02-23            14  34.28 -116.17      55.77
# 2006-02-24            14  34.28 -116.17      55.77
# 2006-02-25            14  34.28 -116.17      55.77
# 2006-02-26            14  34.28 -116.17      55.77
# 2006-02-27            14  34.28 -116.17      55.77
# 2006-02-28            14  34.28 -116.17      55.77
# 2006-03-01            14  34.28 -116.17      55.77
#                      ...    ...     ...        ...
#
# [251292 rows x 8 columns]
