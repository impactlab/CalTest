# %%
__author__="Matthew Gee"
import pandas as pd
import statsmodels.api as sm
import numpy as np

raw_weather = "/Users/matthewgee/Projects/CalTest/data/weather/CalTrack_Complete_Temps.csv"
rename_dict  = {'usaf':'station_number', 'temps':'tempurature','date':'date','CliZn':'climate_zone','Lat':'lat','Lon':'long','Elevation':'elevation'}

df = pd.read_csv(raw_weather, parse_dates=True)
df = df.rename(columns=rename_dict)
#date = df.date.astype(int)
df.date = pd.to_datetime(df.date)
df.dtypes
#ave = df.groupby(['station_number']).apply(np.mean)
#ave
# Out:
# station_number             int64
# date              datetime64[ns]
# tempurature              float64
# WthrStationNum             int64
# climate_zone               int64
# lat                      float64
# long                     float64
# elevation                float64
# dtype: object

# %%
#df['date'] = pd.DatetimeIndex(df['date'])
#date = df['date']
#data = df.index.day

df = df.set_index([df['date']])
testnum =42

df
#data = df.groupby([df['station_number'],df.index.month,df.index.day]).tempurature.mean()
#data = df[['station_number','date']]
var = 'hdd' + str(testnum)
data[var] = 
data
#grouped = df.groupby([date.day,date.month]

#date.year
#df.groupby(['station_number',])
# Out:
#             station_number       date  hdd42
# date
# 2006-01-01          690150 2006-01-01      1
# 2006-01-02          690150 2006-01-02      1
# 2006-01-03          690150 2006-01-03      1
# 2006-01-04          690150 2006-01-04      1
# 2006-01-05          690150 2006-01-05      1
# 2006-01-06          690150 2006-01-06      1
# 2006-01-07          690150 2006-01-07      1
# 2006-01-08          690150 2006-01-08      1
# 2006-01-09          690150 2006-01-09      1
# 2006-01-10          690150 2006-01-10      1
# 2006-01-11          690150 2006-01-11      1
# 2006-01-12          690150 2006-01-12      1
# 2006-01-13          690150 2006-01-13      1
# 2006-01-14          690150 2006-01-14      1
# 2006-01-15          690150 2006-01-15      1
# 2006-01-16          690150 2006-01-16      1
# 2006-01-17          690150 2006-01-17      1
# 2006-01-18          690150 2006-01-18      1
# 2006-01-19          690150 2006-01-19      1
# 2006-01-20          690150 2006-01-20      1
# 2006-01-21          690150 2006-01-21      1
# 2006-01-22          690150 2006-01-22      1
# 2006-01-23          690150 2006-01-23      1
# 2006-01-24          690150 2006-01-24      1
# 2006-01-25          690150 2006-01-25      1
# 2006-01-26          690150 2006-01-26      1
# 2006-01-27          690150 2006-01-27      1
# 2006-01-28          690150 2006-01-28      1
# 2006-01-29          690150 2006-01-29      1
# 2006-01-30          690150 2006-01-30      1
# 2006-01-31          690150 2006-01-31      1
# 2006-02-01          690150 2006-02-01      1
# 2006-02-02          690150 2006-02-02      1
# 2006-02-03          690150 2006-02-03      1
# 2006-02-04          690150 2006-02-04      1
# 2006-02-05          690150 2006-02-05      1
# 2006-02-06          690150 2006-02-06      1
# 2006-02-07          690150 2006-02-07      1
# 2006-02-08          690150 2006-02-08      1
# 2006-02-09          690150 2006-02-09      1
# 2006-02-10          690150 2006-02-10      1
# 2006-02-11          690150 2006-02-11      1
# 2006-02-12          690150 2006-02-12      1
# 2006-02-13          690150 2006-02-13      1
# 2006-02-14          690150 2006-02-14      1
# 2006-02-15          690150 2006-02-15      1
# 2006-02-16          690150 2006-02-16      1
# 2006-02-17          690150 2006-02-17      1
# 2006-02-18          690150 2006-02-18      1
# 2006-02-19          690150 2006-02-19      1
# 2006-02-20          690150 2006-02-20      1
# 2006-02-21          690150 2006-02-21      1
# 2006-02-22          690150 2006-02-22      1
# 2006-02-23          690150 2006-02-23      1
# 2006-02-24          690150 2006-02-24      1
# 2006-02-25          690150 2006-02-25      1
# 2006-02-26          690150 2006-02-26      1
# 2006-02-27          690150 2006-02-27      1
# 2006-02-28          690150 2006-02-28      1
# 2006-03-01          690150 2006-03-01      1
#                        ...        ...    ...
#
# [251292 rows x 3 columns]

# %%
date = pd.to_datetime(df['date'])
date.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-b87bc461c269> in <module>()
#       1 date = pd.to_datetime(df['date'])
# ----> 2 date.hour
#
# /Users/matthewgee/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    1813                 return self[name]
#    1814             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1815                                  (type(self).__name__, name))
#    1816
#    1817     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'hour'
